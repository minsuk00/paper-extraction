# %% [markdown]
# # Loading n-PDFs

# %%
from pyalex import Works
import sys
import os

sys.path.append("../code")
from util import list_to_text_file, get_string_from_text_file

works = (
    Works()
    .filter(is_oa=True)
    .select(["open_access", "display_name"])
    .get(per_page=100, page=1)
)

# %%
import requests
import os

TIMEOUT = 15


# move to util?
def extract_url_to_pdf(data_dir, url: str, filename: str) -> bool:
    try:
        print(f"trying to get pdf from {url}...")
        response = requests.get(url, timeout=TIMEOUT)
        if response.status_code != 200:
            raise Exception("Request GET error. status code not 200")

        PDF_DIR = os.path.join(data_dir, "PDF")
        output_path = os.path.join(PDF_DIR, filename + ".pdf")

        with open(output_path, "wb") as f:
            f.write(response.content)
        return True
    except Exception as e:
        print(f"Could not extract pdf from url. Error: {e}")
        return False

# %%
def parse_n_papers_to_pdf_file(num_papers: int):
    DATA_DIR = "../unilex-transcript/data"
    output_list = get_string_from_text_file(
        os.path.join(DATA_DIR, "extraction_paper_list.txt"), full_path=True
    ).splitlines()
    exception_list = get_string_from_text_file(
        os.path.join(DATA_DIR, "extraction_paper_exception_list.txt"), full_path=True
    ).splitlines()
    output_list = [paper for paper in output_list if paper not in exception_list]
    output_cnt = len(output_list)

    added_cnt = 0
    page_idx = 0
    while output_cnt < num_papers:
        page_idx += 1
        works = (
            Works()
            .filter(is_oa=True)
            .select(["open_access", "display_name"])
            .get(per_page=100, page=page_idx)
        )
        for work in works:
            try:
                url = work["open_access"]["oa_url"]
                name = work["display_name"]
                name = name.replace(" ", "_")
                if name in exception_list:
                    continue
                if name is None:
                    raise Exception("name is NoneType")
                if name not in output_list:
                    print("")
                    if not extract_url_to_pdf(DATA_DIR, url, filename=name):
                        raise Exception("could not extract pdf from url")
                    output_list.append(name)
                    output_cnt += 1
                    added_cnt += 1
                    print(f"\n====={output_cnt} pdfs in output list=====\n")
                if output_cnt >= num_papers:
                    break
            except Exception as e:
                if name:
                    exception_list.append(name)
                print("Error msg:")
                print(e)

        list_to_text_file(
            exception_list,
            os.path.join(DATA_DIR, "extraction_paper_exception_list.txt"),
        )
        list_to_text_file(
            output_list,
            os.path.join(DATA_DIR, "extraction_paper_list.txt"),
        )

    print(f"##### FINISHED. {added_cnt} papers added to list #####")

# %%
parse_n_papers_to_pdf_file(200)
# Out:
# Error msg:
# 'NoneType' object has no attribute 'replace'
#
# trying to get pdf from http://www.public.asu.edu/%7Edavidpm/classes/psy536/Baron.pdf...
#
# =====11 pdfs in output list=====
#
#
# trying to get pdf from https://europepmc.org/articles/pmc450244?pdf=render...
#
# =====12 pdfs in output list=====
#
#
# trying to get pdf from http://link.aps.org/pdf/10.1103/PhysRev.140.A1133...
#
# =====13 pdfs in output list=====
#
#
# trying to get pdf from http://www.cell.com/article/S0092867411001279/pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://onlinelibrary.wiley.com/doi/pdfdirect/10.3322/caac.21660...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://www.jstatsoft.org/index.php/jss/article/view/v067i01/v67i01.pdf...
# Could not extract pdf from url. Error: [Errno 2] No such file or directory: '../unilex-transcript/data/PDF/Fitting_Linear_Mixed-Effects_Models_Using<b>lme4</b>.pdf'
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://europepmc.org/articles/pmc411572?pdf=render...
#
# =====14 pdfs in output list=====
#
#
# trying to get pdf from https://journals.plos.org/plosmedicine/article/file?id=10.1371/journal.pmed.1000097&type=printable...
#
# =====15 pdfs in output list=====
#
#
# trying to get pdf from https://academic.oup.com/bioinformatics/article-pdf/25/16/2078/48994296/bioinformatics_25_16_2078.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://europepmc.org/articles/pmc192859?pdf=render...
#
# =====16 pdfs in output list=====
#
#
# trying to get pdf from http://conservancy.umn.edu/bitstream/11299/98561/1/v01n3p385.pdf...
#
# =====17 pdfs in output list=====
#
#
# trying to get pdf from https://europepmc.org/articles/pmc3855844?pdf=render...
#
# =====18 pdfs in output list=====
#
#
# trying to get pdf from https://europepmc.org/articles/pmc5554542?pdf=render...
#
# =====19 pdfs in output list=====
#
#
# trying to get pdf from https://karger.com/cpb/article-pdf/31/4-5/683/2424835/000350087.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from http://link.aps.org/pdf/10.1103/PhysRev.136.B864...
#
# =====20 pdfs in output list=====
#
#
# trying to get pdf from https://repositorio.unal.edu.co/bitstream/unal/75703/1/81721105.2020.pdf...
# Could not extract pdf from url. Error: HTTPSConnectionPool(host='repositorio.unal.edu.co', port=443): Read timed out. (read timeout=15)
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/bioinformatics/article-pdf/30/15/2114/48924714/bioinformatics_30_15_2114.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://europepmc.org/articles/pmc2127453?pdf=render...
#
# =====21 pdfs in output list=====
#
#
# trying to get pdf from https://academic.oup.com/bioinformatics/article-pdf/25/14/1754/48994219/bioinformatics_25_14_1754.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://hal.science/hal-03926082/document...
#
# =====22 pdfs in output list=====
#
#
# trying to get pdf from https://link.springer.com/content/pdf/10.3758%2FBF03193146.pdf...
#
# =====23 pdfs in output list=====
#
#
# trying to get pdf from https://europepmc.org/articles/pmc3322381...
#
# =====24 pdfs in output list=====
#
#
# trying to get pdf from https://www.bmj.com/content/bmj/339/bmj.b2535.full.pdf...
#
# =====25 pdfs in output list=====
#
#
# trying to get pdf from https://europepmc.org/articles/pmc1239896?pdf=render...
#
# =====26 pdfs in output list=====
#
#
# trying to get pdf from https://projecteuclid.org/journals/annals-of-statistics/volume-6/issue-2/Estimating-the-Dimension-of-a-Model/10.1214/aos/1176344136.pdf...
#
# =====27 pdfs in output list=====
#
#
# trying to get pdf from https://academic.oup.com/mbe/article-pdf/30/12/2725/19498310/mst197.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/mbe/article-pdf/28/10/2731/2954190/msr121.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://europepmc.org/articles/pmc147148?pdf=render...
#
# =====28 pdfs in output list=====
#
#
# trying to get pdf from http://www.cgl.ucsf.edu/home/tef/pubs/chimera.pdf...
#
# =====29 pdfs in output list=====
#
#
# trying to get pdf from https://doi.org/10.1016/s0140-6736(20)30183-5...
#
# =====30 pdfs in output list=====
#
#
# trying to get pdf from https://digital.library.unt.edu/ark:/67531/metadc1389173/m2/1/high_res_d/10176421.pdf...
#
# =====31 pdfs in output list=====
#
#
# trying to get pdf from https://academic.oup.com/nar/article-pdf/32/5/1792/7055030/gkh340.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://genome.cshlp.org/content/13/11/2498.full.pdf...
#
# =====32 pdfs in output list=====
#
#
# trying to get pdf from https://zenodo.org/record/6487417/files/DEB%20NSGA%20ORIGINAL.pdf...
#
# =====33 pdfs in output list=====
#
#
# trying to get pdf from https://onlinelibrary.wiley.com/doi/pdfdirect/10.3322/caac.20107...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from http://www.dklevine.com/archive/refs47656.pdf...
#
# =====34 pdfs in output list=====
#
#
# trying to get pdf from https://europepmc.org/articles/pmc3037419?pdf=render...
#
# =====35 pdfs in output list=====
#
#
# trying to get pdf from https://academic.oup.com/mbe/article-pdf/33/7/1870/7948752/msw054.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/bioinformatics/article-pdf/29/1/15/17101697/bts635.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from http://repository.ucatolica.edu.co/bitstreams/939d5226-d105-482b-81f4-7e8f92c80477/download...
#
# =====36 pdfs in output list=====
#
#
# trying to get pdf from https://www.osti.gov/biblio/4390578...
#
# =====37 pdfs in output list=====
#
#
# trying to get pdf from https://europepmc.org/articles/pmc2700030?pdf=render...
#
# =====38 pdfs in output list=====
#
#
# trying to get pdf from https://www.ncbi.nlm.nih.gov/pmc/articles/PMC102472...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from http://www.cell.com/article/S0092867404000455/pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://link.springer.com/content/pdf/10.1007/978-3-319-24574-4_28.pdf...
#
# =====39 pdfs in output list=====
#
#
# trying to get pdf from https://arxiv.org/pdf/cond-mat/9910332...
#
# =====40 pdfs in output list=====
#
#
# trying to get pdf from https://academic.oup.com/bioinformatics/article-pdf/26/1/139/48851299/bioinformatics_26_1_139.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/mbe/article-pdf/30/4/772/6420419/mst010.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from http://journals.iucr.org/c/issues/2015/01/00/fa3356/fa3356.pdf...
# Could not extract pdf from url. Error: [Errno 2] No such file or directory: '../unilex-transcript/data/PDF/Crystal_structure_refinement_with<i>SHELXL</i>.pdf'
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://dspace.mit.edu/bitstream/1721.1/104944/1/11263_2015_Article_816.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://arxiv.org/pdf/1409.4842...
#
# =====41 pdfs in output list=====
#
#
# trying to get pdf from https://academic.oup.com/nar/article-pdf/29/9/e45/9901003/2900e45.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1495268...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/clinchem/article-pdf/18/6/499/31894188/clinchem0499.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://europepmc.org/articles/pmc3156573?pdf=render...
#
# =====42 pdfs in output list=====
#
#
# trying to get pdf from https://link.springer.com/content/pdf/10.1007/BF00280883.pdf...
#
# =====43 pdfs in output list=====
#
#
# trying to get pdf from https://link.springer.com/content/pdf/10.1007/BF00994018.pdf...
#
# =====44 pdfs in output list=====
#
#
# trying to get pdf from https://academic.oup.com/mbe/article-pdf/24/8/1596/3858330/msm092.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://jnnp.bmj.com/content/jnnp/23/1/56.full.pdf...
#
# =====45 pdfs in output list=====
#
#
# trying to get pdf from https://onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1558-5646.1985.tb00420.x...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from http://journals.iucr.org/d/issues/2004/12/01/ba5070/ba5070.pdf...
# Could not extract pdf from url. Error: [Errno 2] No such file or directory: '../unilex-transcript/data/PDF/<i>Coot</i>:_model-building_tools_for_molecular_graphics.pdf'
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from http://www.cell.com/article/S0092867400816839/pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://doi.org/10.1086/260062...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from http://www.cell.com/article/S0002929707613524/pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://www.bmj.com/content/bmj/372/bmj.n71.full.pdf...
#
# =====46 pdfs in output list=====
#
#
# trying to get pdf from https://n.neurology.org/content/neurology/34/7/939.full.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://doi.org/10.1007/978-1-4757-2440-0...
#
# =====47 pdfs in output list=====
#
#
# trying to get pdf from https://research.rug.nl/files/64380902/1.448118.pdf...
#
# =====48 pdfs in output list=====
#
#
# trying to get pdf from http://download.clib.psu.ac.th/datawebclib/e_resource/trial_database/WileyInterScienceCD/pdf/SMJ/SMJ_1.pdf...
#
# =====49 pdfs in output list=====
#
#
# trying to get pdf from https://link.springer.com/content/pdf/10.3758/BRM.40.3.879.pdf...
#
# =====50 pdfs in output list=====
#
#
# trying to get pdf from http://journals.ametsoc.org/doi/pdf/10.1175/1520-0477%281996%29077%3C0437%3ATNYRP%3E2.0.CO%3B2...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/bioinformatics/article-pdf/23/21/2947/49823064/bioinformatics_23_21_2947.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://www.karger.com/Article/Pdf/453569...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/bioinformatics/article-pdf/30/9/1312/48923136/bioinformatics_30_9_1312.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://doi.org/10.17265/2159-5313/2016.09.003...
#
# =====51 pdfs in output list=====
#
#
# trying to get pdf from https://doi.org/10.3115/v1/d14-1162...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/mbe/article-pdf/35/6/1547/25091958/msy096.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/genetics/article-pdf/155/2/945/35125695/genetics0945.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://europepmc.org/articles/pmc4402510?pdf=render...
#
# =====52 pdfs in output list=====
#
#
# trying to get pdf from https://zenodo.org/records/1232936/files/article.pdf...
# Could not extract pdf from url. Error: [Errno 2] No such file or directory: '../unilex-transcript/data/PDF/Particle_mesh_Ewald:_An_<i>N</i>⋅log(<i>N</i>)_method_for_Ewald_sums_in_large_systems.pdf'
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://arxiv.org/pdf/1412.6980...
#
# =====53 pdfs in output list=====
#
#
# trying to get pdf from https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1360123...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/biomet/article-pdf/70/1/41/662954/70-1-41.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://rupress.org/jcb/article-pdf/17/1/208/1334038/208.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/bioinformatics/article-pdf/19/12/1572/48904554/bioinformatics_19_12_1572.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://arxiv.org/pdf/1608.06993...
#
# =====54 pdfs in output list=====
#
#
# trying to get pdf from https://onlinelibrary.wiley.com/doi/pdfdirect/10.1002/ijc.29210...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://link.springer.com/content/pdf/10.1007/s00214-007-0310-x.pdf...
# Could not extract pdf from url. Error: [Errno 63] File name too long: '../unilex-transcript/data/PDF/The_M06_suite_of_density_functionals_for_main_group_thermochemistry,_thermochemical_kinetics,_noncovalent_interactions,_excited_states,_and_transition_elements:_two_new_functionals_and_systematic_testing_of_four_M06-class_functionals_and_12_other_functionals.pdf'
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://arxiv.org/pdf/1411.4038...
#
# =====55 pdfs in output list=====
#
#
# trying to get pdf from https://www.bmj.com/content/bmj/343/bmj.d5928.full.pdf...
#
# =====56 pdfs in output list=====
#
#
# trying to get pdf from https://academic.oup.com/nar/article-pdf/28/1/27/9895154/280027.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://onlinelibrary.wiley.com/doi/pdfdirect/10.3322/caac.21262...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://www.karger.com/Article/Pdf/468530...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from http://www.cell.com/article/S0092867406009767/pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from http://journals.iucr.org/d/issues/2010/04/00/ba5144/ba5144.pdf...
# Could not extract pdf from url. Error: [Errno 2] No such file or directory: '../unilex-transcript/data/PDF/Features_and_development_of_<i>Coot</i>.pdf'
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://doi.org/10.3168/jds.s0022-0302(91)78551-2...
#
# =====57 pdfs in output list=====
#
#
# trying to get pdf from http://www.nes.ru/~agoriaev/Papers/Fama-French%205%20factors%20for%20stocks%20and%20vonds%20JFE93.pdf...
#
# =====58 pdfs in output list=====
#
#
# trying to get pdf from https://www.nejm.org/doi/pdf/10.1056/NEJM199309303291401?articleTools=true...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://www.nejm.org/doi/pdf/10.1056/NEJMoa2002032?articleTools=true...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://www.nature.com/articles/35057062.pdf...
#
# =====59 pdfs in output list=====
#
#
# trying to get pdf from https://www.nejm.org/doi/pdf/10.1056/NEJMoa2001017?articleTools=true...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/mbe/article-pdf/4/4/406/11167444/7sait.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://doi.org/10.1016/s0021-9258(19)83641-4...
#
# =====60 pdfs in output list=====
#
#
# trying to get pdf from https://digital.csic.es/bitstream/10261/18097/1/Electronic_properties_graphene.pdf...
#
# =====61 pdfs in output list=====
#
#
# trying to get pdf from https://arxiv.org/pdf/1506.02640...
#
# =====62 pdfs in output list=====
#
#
# trying to get pdf from https://doi.org/10.1016/s0140-6736(20)30566-3...
#
# =====63 pdfs in output list=====
#
#
# trying to get pdf from None...
# Could not extract pdf from url. Error: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from http://dl.acm.org/ft_gateway.cfm?id=3065386&type=pdf...
#
# =====64 pdfs in output list=====
#
#
# trying to get pdf from https://link.springer.com/content/pdf/10.3758/BRM.41.4.1149.pdf...
#
# =====65 pdfs in output list=====
#
#
# trying to get pdf from https://dl.acm.org/doi/pdf/10.1145/358669.358692...
#
# =====66 pdfs in output list=====
#
#
# trying to get pdf from https://genome.cshlp.org/content/20/9/1297.full.pdf...
#
# =====67 pdfs in output list=====
#
#
# trying to get pdf from https://arxiv.org/pdf/1506.01497...
#
# =====68 pdfs in output list=====
#
#
# trying to get pdf from http://www-m3.ma.tum.de/foswiki/pub/MN0506/WebHome/dijkstra.pdf...
# Could not extract pdf from url. Error: HTTPSConnectionPool(host='web.sc.ma.tum.de', port=443): Read timed out. (read timeout=15)
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://doi.org/10.1002/qj.828...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/intqhc/article-pdf/19/6/349/5070113/mzm042.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from http://journals.iucr.org/d/issues/2010/02/00/dz5186/dz5186.pdf...
# Could not extract pdf from url. Error: [Errno 2] No such file or directory: '../unilex-transcript/data/PDF/<i>PHENIX</i>:_a_comprehensive_Python-based_system_for_macromolecular_structure_solution.pdf'
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://www.degruyter.com/document/doi/10.1351/pac198557040603/pdf...
# Could not extract pdf from url. Error: [Errno 2] No such file or directory: '../unilex-transcript/data/PDF/Reporting_physisorption_data_for_gas/solid_systems_with_special_reference_to_the_determination_of_surface_area_and_porosity_(Recommendations_1984).pdf'
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://doi.org/10.1016/s0021-9258(18)94333-4...
#
# =====69 pdfs in output list=====
#
#
# trying to get pdf from https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1392413...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://hal.inria.fr/inria-00548512/file/hog_cvpr2005.pdf...
#
# =====70 pdfs in output list=====
#
#
# trying to get pdf from https://doi.org/10.1038/gim.2015.30...
#
# =====71 pdfs in output list=====
#
#
# trying to get pdf from https://academic.oup.com/bioinformatics/article-pdf/17/8/754/48837190/bioinformatics_17_8_754.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/bioinformatics/article-pdf/26/6/841/48854754/bioinformatics_26_6_841.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/nar/article-pdf/41/D1/D590/3690367/gks1219.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://europepmc.org/articles/pmc3339379?pdf=render...
#
# =====72 pdfs in output list=====
#
#
# trying to get pdf from https://journal.embnet.org/index.php/embnetjournal/article/download/200/458...
#
# =====73 pdfs in output list=====
#
#
# trying to get pdf from https://academic.oup.com/plphys/article-pdf/24/1/1/35642566/plphys_v24_1_1.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/sysbio/article-pdf/61/3/539/24563565/sys029.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://arxiv.org/pdf/cond-mat/0509330...
#
# =====74 pdfs in output list=====
#
#
# trying to get pdf from https://estudogeral.uc.pt/bitstream/10316/2535/1/Doutor%20Fiolhais%201.pdf...
#
# =====75 pdfs in output list=====
#
#
# trying to get pdf from https://europepmc.org/articles/pmc2763564?pdf=render...
#
# =====76 pdfs in output list=====
#
#
# trying to get pdf from None...
# Could not extract pdf from url. Error: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://genomebiology.biomedcentral.com/counter/pdf/10.1186/gb-2009-10-3-r25...
#
# =====77 pdfs in output list=====
#
#
# trying to get pdf from https://repository.upenn.edu/cgi/viewcontent.cgi?article=1703&context=cis_reports...
#
# =====78 pdfs in output list=====
#
#
# trying to get pdf from https://www.karger.com/Article/Pdf/454668...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://arxiv.org/pdf/1311.2524...
#
# =====79 pdfs in output list=====
#
#
# trying to get pdf from http://www.eeri.eu/documents/wp/EERI_RP_1986_01.pdf...
#
# =====80 pdfs in output list=====
#
#
# trying to get pdf from https://doi.org/10.1016/s0021-9258(19)41496-8...
#
# =====81 pdfs in output list=====
#
#
# trying to get pdf from https://infoscience.epfl.ch/record/49909/files/Ago+03.pdf...
#
# =====82 pdfs in output list=====
#
#
# trying to get pdf from http://link.aps.org/pdf/10.1103/PhysRevB.23.5048...
#
# =====83 pdfs in output list=====
#
#
# trying to get pdf from http://dl.acm.org/ft_gateway.cfm?id=2939785&type=pdf...
#
# =====84 pdfs in output list=====
#
#
# trying to get pdf from https://doi.org/10.1001/archinte.166.10.1092...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/nar/article-pdf/16/3/1215/4063153/16-3-1215.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://cdnsciencepub.com/doi/pdf/10.1139/p80-159...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://europepmc.org/articles/pmc3342519?pdf=render...
#
# =====85 pdfs in output list=====
#
#
# trying to get pdf from https://serval.unil.ch/resource/serval:BIB_2B5D8C9C02FA.P001/REF.pdf...
# Could not extract pdf from url. Error: [Errno 2] No such file or directory: '../unilex-transcript/data/PDF/Detecting_the_number_of_clusters_of_individuals_using_the_software_<scp>structure</scp>:_a_simulation_study.pdf'
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://doi.org/10.1002/art.1780310302...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from http://journals.iucr.org/a/issues/2015/01/00/sc5086/sc5086.pdf...
# Could not extract pdf from url. Error: [Errno 2] No such file or directory: '../unilex-transcript/data/PDF/<i>SHELXT</i>–_Integrated_space-group_and_crystal-structure_determination.pdf'
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://arxiv.org/pdf/cond-mat/0106096...
#
# =====86 pdfs in output list=====
#
#
# trying to get pdf from https://zenodo.org/records/1429050/files/article.pdf...
#
# =====87 pdfs in output list=====
#
#
# trying to get pdf from http://www.sccn.ucsd.edu/eeglab/download/eeglab_jnm03.pdf...
#
# =====88 pdfs in output list=====
#
#
# trying to get pdf from https://infoscience.epfl.ch/record/141807/files/quantum_espresso.pdf...
#
# =====89 pdfs in output list=====
#
#
# trying to get pdf from http://www.stat.duke.edu/~scs/Courses/Stat376/Papers/Constraints/Shake1977.pdf...
# Could not extract pdf from url. Error: HTTPSConnectionPool(host='www2.stat.duke.edu', port=443): Max retries exceeded with url: /homeweb/scs/Courses/Stat376/Papers/Constraints/Shake1977.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)')))
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from http://journals.iucr.org/j/issues/2007/04/00/he5368/he5368.pdf...
# Could not extract pdf from url. Error: [Errno 2] No such file or directory: '../unilex-transcript/data/PDF/<i>Phaser</i>crystallographic_software.pdf'
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://hal.science/hal-04014501/document...
#
# =====90 pdfs in output list=====
#
#
# trying to get pdf from http://www.cell.com/article/S0092867407014717/pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/schizophreniabulletin/article-pdf/13/2/261/5413519/13-2-261.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://www.jair.org/index.php/jair/article/download/10302/24590...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://omsorgsforskning.brage.unit.no/omsorgsforskning-xmlui/bitstream/11250/2477738/1/Arksey.pdf...
#
# =====91 pdfs in output list=====
#
#
# trying to get pdf from https://doi.org/10.1016/s0021-9258(18)84756-1...
#
# =====92 pdfs in output list=====
#
#
# trying to get pdf from https://expeditiorepositorio.utadeo.edu.co/bitstream/20.500.12010/27586/1/PROYECTO-%20CARLOS%20JOVANY%20MESA%20CASTILLO..pdf...
#
# =====93 pdfs in output list=====
#
#
# trying to get pdf from http://www.cell.com/article/S0092867409000087/pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://arxiv.org/pdf/1512.00567...
#
# =====94 pdfs in output list=====
#
#
# trying to get pdf from https://europepmc.org/articles/pmc3041641?pdf=render...
#
# =====95 pdfs in output list=====
#
#
# trying to get pdf from https://europepmc.org/articles/pmc4927377?pdf=render...
#
# =====96 pdfs in output list=====
#
#
# trying to get pdf from https://doi.org/10.1001/jama.2013.281053...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://doi.org/10.1001/jama.2020.1585...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://www.nejm.org/doi/pdf/10.1056/NEJMoa043330?articleTools=true...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://doi.org/10.1128/aem.01541-09...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/biomedgerontology/article-pdf/56/3/M146/9743160/M146.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/bioinformatics/article-pdf/26/19/2460/48857155/bioinformatics_26_19_2460.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://www.nature.com/articles/s41592-019-0686-2.pdf...
#
# =====97 pdfs in output list=====
#
#
# trying to get pdf from https://www.nature.com/articles/s41586-021-03819-2.pdf...
#
# =====98 pdfs in output list=====
#
#
# trying to get pdf from https://www.nature.com/articles/s41586-020-2012-7.pdf...
#
# =====99 pdfs in output list=====
#
#
# trying to get pdf from https://www.nejm.org/doi/pdf/10.1056/NEJMoa012512?articleTools=true...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://europepmc.org/articles/pmc2760638?pdf=render...
#
# =====100 pdfs in output list=====
#
#
# trying to get pdf from https://acsjournals.onlinelibrary.wiley.com/doi/pdfdirect/10.3322/caac.21551...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://jamanetwork.com/journals/jama/articlepdf/2492881/jsc160002.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://arxiv.org/pdf/1002.3895...
# Could not extract pdf from url. Error: [Errno 2] No such file or directory: '../unilex-transcript/data/PDF/<i>Colloquium</i>:_Topological_insulators.pdf'
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://europepmc.org/articles/pmc3571712?pdf=render...
#
# =====101 pdfs in output list=====
#
#
# trying to get pdf from https://systematicreviewsjournal.biomedcentral.com/counter/pdf/10.1186/2046-4053-4-1...
#
# =====102 pdfs in output list=====
#
#
# trying to get pdf from https://arxiv.org/pdf/cond-mat/0303516...
#
# =====103 pdfs in output list=====
#
#
# trying to get pdf from https://link.springer.com/content/pdf/10.1007%2F978-3-319-10602-1_48.pdf...
#
# =====104 pdfs in output list=====
#
#
# trying to get pdf from https://europepmc.org/articles/pmc346238?pdf=render...
#
# =====105 pdfs in output list=====
#
#
# trying to get pdf from https://onlinelibrary.wiley.com/doi/pdfdirect/10.3322/canjclin.55.2.74...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
# Error msg:
# 'NoneType' object has no attribute 'replace'
#
# trying to get pdf from http://www.cell.com/article/S0092867420302294/pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://dspace.mit.edu/bitstream/1721.1/2068/1/SWP-1523-15376412.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/bioinformatics/article-pdf/30/7/923/633148/btt656.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://doi.org/10.1128/aem.00062-07...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://doi.org/10.1086/261420...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://acsjournals.onlinelibrary.wiley.com/doi/pdfdirect/10.3322/caac.21590...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/biomet/article-pdf/73/1/13/679793/73-1-13.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/bioinformatics/article-pdf/31/2/166/49011133/bioinformatics_31_2_166.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://telearn.archives-ouvertes.fr/hal-00190571/document/...
#
# =====106 pdfs in output list=====
#
#
# trying to get pdf from http://www.decom.ufop.br/menotti/rp112/slides/13-2006-AnIntroductionToROCAnalysis-PRLv27pp861-874.pdf...
#
# =====107 pdfs in output list=====
#
#
# trying to get pdf from http://www.thelancet.com/article/S0140673620302117/pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://karger.com/dee/article-pdf/3/1/360/2562810/000353441.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://doi.org/10.1016/s0021-9258(19)42083-8...
#
# =====108 pdfs in output list=====
#
#
# trying to get pdf from https://academic.oup.com/sysbio/article-pdf/52/5/696/19503129/52-5-696.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://bmcbioinformatics.biomedcentral.com/counter/pdf/10.1186/1471-2105-9-559...
#
# =====109 pdfs in output list=====
#
#
# trying to get pdf from https://journals.ametsoc.org/downloadpdf/journals/atsc/20/2/1520-0469_1963_020_0130_dnf_2_0_co_2.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/mbe/article-pdf/32/1/268/13171186/msu300.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://onlinelibrary.wiley.com/doi/pdfdirect/10.1002/ijc.25516...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://europepmc.org/articles/pmc24541?pdf=render...
#
# =====110 pdfs in output list=====
#
#
# trying to get pdf from https://repositorio.unal.edu.co/bitstream/unal/81108/3/1030612399.2022.pdf...
# Could not extract pdf from url. Error: HTTPSConnectionPool(host='repositorio.unal.edu.co', port=443): Read timed out. (read timeout=15)
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://projecteuclid.org/journals/annals-of-mathematical-statistics/volume-22/issue-1/On-Information-and-Sufficiency/10.1214/aoms/1177729694.pdf...
#
# =====111 pdfs in output list=====
#
#
# trying to get pdf from https://karger.com/imi/article-pdf/1/4/211/3000618/000368408.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from None...
# Could not extract pdf from url. Error: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://www.nature.com/articles/nature11247.pdf...
#
# =====112 pdfs in output list=====
#
#
# trying to get pdf from http://cindy.informatik.uni-bremen.de/cosy/teaching/CM_2011/Eval3/pe_efron_93.pdf...
#
# =====113 pdfs in output list=====
#
#
# trying to get pdf from https://pure.mpg.de/pubman/item/item_2389918_2/component/file_2389917/Stroop_1935_Studies.pdf...
#
# =====114 pdfs in output list=====
#
#
# trying to get pdf from https://onlinelibrary.wiley.com/doi/pdfdirect/10.1002/jcc.20289...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/bioinformatics/article-pdf/28/12/1647/48879775/bioinformatics_28_12_1647.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://doi.org/10.1249/01.mss.0000078924.61453.fb...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://projecteuclid.org/journals/annals-of-statistics/volume-29/issue-5/Greedy-function-approximation-A-gradient-boosting-machine/10.1214/aos/1013203451.pdf...
#
# =====115 pdfs in output list=====
#
#
# trying to get pdf from https://iopscience.iop.org/article/10.1086/300499/pdf...
#
# =====116 pdfs in output list=====
#
#
# trying to get pdf from https://dl.acm.org/action/downloadSupplement?doi=10.1145%2F1327452.1327492&file=p107-dean.jp.pdf...
#
# =====117 pdfs in output list=====
#
#
# trying to get pdf from https://zenodo.org/records/1235949/files/article.pdf...
#
# =====118 pdfs in output list=====
#
#
# trying to get pdf from https://doi.org/10.1016/s0021-9258(18)57021-6...
#
# =====119 pdfs in output list=====
#
#
# trying to get pdf from https://karger.com/ger/article-pdf/62/2/226/2837897/000430949.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://bmcbioinformatics.biomedcentral.com/counter/pdf/10.1186/1471-2105-12-323...
#
# =====120 pdfs in output list=====
#
#
# trying to get pdf from https://europepmc.org/articles/pmc342324?pdf=render...
#
# =====121 pdfs in output list=====
#
#
# trying to get pdf from https://academic.oup.com/jrsssb/article-pdf/67/2/301/49795094/jrsssb_67_2_301.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://doi.org/10.1107/s0021889869006558...
#
# =====122 pdfs in output list=====
#
#
# trying to get pdf from https://arxiv.org/pdf/1612.03144...
#
# =====123 pdfs in output list=====
#
#
# trying to get pdf from https://eprints.whiterose.ac.uk/136633/1/PRISMA_ScR_Manuscript_July6th_clean_1_.pdf...
#
# =====124 pdfs in output list=====
#
#
# trying to get pdf from http://www.ucl.ac.uk/~uctp39a/Blundell-Bond-1998.pdf...
#
# =====125 pdfs in output list=====
#
#
# trying to get pdf from https://europepmc.org/articles/pmc4655817?pdf=render...
#
# =====126 pdfs in output list=====
#
#
# trying to get pdf from https://dspace.mit.edu/bitstream/1721.1/64309/1/specificationtes00haus.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://projecteuclid.org/journals/annals-of-statistics/volume-7/issue-1/Bootstrap-Methods-Another-Look-at-the-Jackknife/10.1214/aos/1176344552.pdf...
#
# =====127 pdfs in output list=====
#
#
# trying to get pdf from https://doi.org/10.1126/science.282.5391.1145...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://care.diabetesjournals.org/content/diacare/27/5/1047.full.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://europepmc.org/articles/pmc321012?pdf=render...
#
# =====128 pdfs in output list=====
#
#
# trying to get pdf from https://academic.oup.com/sysbio/article-pdf/59/3/307/24207259/syq010.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from http://www.ee.duke.edu/~lcarin/01580791.pdf...
# Could not extract pdf from url. Error: HTTPSConnectionPool(host='people.ee.duke.edu', port=443): Max retries exceeded with url: /~lcarin/01580791.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)')))
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://doi.org/10.1006/jcss.1997.1504...
#
# =====129 pdfs in output list=====
#
#
# trying to get pdf from https://iopscience.iop.org/article/10.1086/307221/pdf...
#
# =====130 pdfs in output list=====
#
#
# trying to get pdf from https://acsjournals.onlinelibrary.wiley.com/doi/pdfdirect/10.3322/caac.21332...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://jamanetwork.com/journals/jama/articlepdf/195120/joc21036.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://dl.acm.org/doi/pdf/10.3115/1073083.1073135...
#
# =====131 pdfs in output list=====
#
#
# trying to get pdf from https://hal.insa-toulouse.fr/hal-01969513/document...
#
# =====132 pdfs in output list=====
#
#
# trying to get pdf from https://repositorio.unal.edu.co/bitstream/unal/82353/4/1090424173.2021.pdf...
# Could not extract pdf from url. Error: HTTPSConnectionPool(host='repositorio.unal.edu.co', port=443): Read timed out. (read timeout=15)
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://journals.plos.org/plosmedicine/article/file?id=10.1371/journal.pmed.1000100&type=printable...
#
# =====133 pdfs in output list=====
#
#
# trying to get pdf from https://hal.science/hal-01577887/document...
#
# =====134 pdfs in output list=====
#
#
# trying to get pdf from https://aclanthology.org/D14-1179.pdf...
#
# =====135 pdfs in output list=====
#
#
# trying to get pdf from https://www.bmj.com/content/bmj/320/7244/1240.full.pdf...
#
# =====136 pdfs in output list=====
#
#
# trying to get pdf from https://europepmc.org/articles/pmc2335261?pdf=render...
#
# =====137 pdfs in output list=====
#
#
# trying to get pdf from https://doi.org/10.1016/j.softx.2015.06.001...
#
# =====138 pdfs in output list=====
#
#
# trying to get pdf from https://hal.science/hal-02417326/document...
#
# =====139 pdfs in output list=====
#
#
# trying to get pdf from https://europepmc.org/articles/pmc4913118?pdf=render...
#
# =====140 pdfs in output list=====
#
#
# trying to get pdf from https://doi.org/10.1001/jama.2020.2648...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://acsjournals.onlinelibrary.wiley.com/doi/pdfdirect/10.3322/caac.21442...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://revistas.uptc.edu.co/index.php/ingenieria/article/download/5834/4728...
#
# =====141 pdfs in output list=====
#
#
# trying to get pdf from https://revistaseug.ugr.es/index.php/profesorado/article/download/11230/9309...
#
# =====142 pdfs in output list=====
#
#
# trying to get pdf from https://doi.org/10.18637/jss.v048.i02...
# Could not extract pdf from url. Error: [Errno 2] No such file or directory: '../unilex-transcript/data/PDF/<b>lavaan</b>:_An<i>R</i>Package_for_Structural_Equation_Modeling.pdf'
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://intellectum.unisabana.edu.co/bitstream/10818/15120/1/Podcasting%20as%20a%20way%20to%20improve%20teacher%20trainees.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://europepmc.org/articles/pmc1215910?pdf=render...
#
# =====143 pdfs in output list=====
#
#
# trying to get pdf from http://www.nber.org/papers/t0055.pdf...
#
# =====144 pdfs in output list=====
#
#
# trying to get pdf from https://onlinelibrary.wiley.com/doi/pdfdirect/10.1002/jcc.20035...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://link.springer.com/content/pdf/10.1007/s11747-014-0403-8.pdf...
#
# =====145 pdfs in output list=====
#
#
# trying to get pdf from https://academic.oup.com/sleep/article-pdf/14/6/540/21735916/140611.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://link.springer.com/content/pdf/10.3758/BF03206553.pdf...
#
# =====146 pdfs in output list=====
#
#
# trying to get pdf from https://acsjournals.onlinelibrary.wiley.com/doi/pdfdirect/10.3322/caac.21338...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://arxiv.org/pdf/1708.02002...
#
# =====147 pdfs in output list=====
#
#
# trying to get pdf from https://pure.mpg.de/pubman/item/item_588952_3/component/file_588951/412029.pdf...
#
# =====148 pdfs in output list=====
#
#
# trying to get pdf from https://www.pure.ed.ac.uk/ws/files/7879113/ijcv_voc09.pdf...
#
# =====149 pdfs in output list=====
#
#
# trying to get pdf from https://bmcbioinformatics.biomedcentral.com/counter/pdf/10.1186/1471-2105-10-421...
#
# =====150 pdfs in output list=====
#
#
# trying to get pdf from https://journals.sagepub.com/doi/pdf/10.1177/29.4.6166661...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://cdr.lib.unc.edu/downloads/p5547t54k...
#
# =====151 pdfs in output list=====
#
#
# trying to get pdf from https://europepmc.org/articles/pmc2008650?pdf=render...
#
# =====152 pdfs in output list=====
#
#
# trying to get pdf from https://arxiv.org/pdf/1404.7828...
#
# =====153 pdfs in output list=====
#
#
# trying to get pdf from http://journals.iucr.org/d/issues/2010/02/00/dz5179/dz5179.pdf...
# Could not extract pdf from url. Error: [Errno 2] No such file or directory: '../unilex-transcript/data/PDF/<i>XDS</i>.pdf'
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from http://link.aps.org/pdf/10.1103/PhysRevLett.56.930...
#
# =====154 pdfs in output list=====
#
#
# trying to get pdf from https://infoscience.epfl.ch/record/182177/files/Nat Nano 7 699 (2012) Wang - Electronics and optoelectronics of two-dimensional transition metal dichalcogenides.pdf...
#
# =====155 pdfs in output list=====
#
#
# trying to get pdf from https://www.nature.com/articles/nature15393.pdf...
#
# =====156 pdfs in output list=====
#
#
# trying to get pdf from https://academic.oup.com/bioinformatics/article-pdf/25/11/1451/48986663/bioinformatics_25_11_1451.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://journals.iucr.org/j/issues/1991/05/00/gl0206/gl0206.pdf...
#
# =====157 pdfs in output list=====
#
#
# trying to get pdf from https://authors.library.caltech.edu/1753/1/MOLpr34.pdf...
#
# =====158 pdfs in output list=====
#
#
# trying to get pdf from http://link.aps.org/pdf/10.1103/PhysRev.47.777...
#
# =====159 pdfs in output list=====
#
#
# trying to get pdf from https://escholarship.org/content/qt6qc3614q/qt6qc3614q.pdf?t=lnrimp...
#
# =====160 pdfs in output list=====
#
#
# trying to get pdf from http://journals.iucr.org/d/issues/2009/02/00/ba5124/ba5124.pdf...
#
# =====161 pdfs in output list=====
#
#
# trying to get pdf from https://link.springer.com/content/pdf/10.1007/BF00058655.pdf...
#
# =====162 pdfs in output list=====
#
#
# trying to get pdf from https://www.bmj.com/content/bmj/339/bmj.b2700.full.pdf...
#
# =====163 pdfs in output list=====
#
#
# trying to get pdf from https://repositorio.unal.edu.co/bitstream/unal/82529/2/98562187.2022.pdf...
# Could not extract pdf from url. Error: HTTPSConnectionPool(host='repositorio.unal.edu.co', port=443): Read timed out. (read timeout=15)
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://doi.org/10.1073/pnas.120163297...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://genomebiology.biomedcentral.com/counter/pdf/10.1186/gb-2008-9-9-r137...
#
# =====164 pdfs in output list=====
#
#
# trying to get pdf from https://arxiv.org/pdf/1606.00915...
#
# =====165 pdfs in output list=====
#
#
# trying to get pdf from https://acsjournals.onlinelibrary.wiley.com/doi/pdfdirect/10.3322/caac.21387...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/bioinformatics/article-pdf/21/2/263/456887/bth457.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1755-0998.2010.02847.x...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://doi.org/10.1016/0377-0427(87)90125-7...
#
# =====166 pdfs in output list=====
#
#
# trying to get pdf from http://www.cin.ufpe.br/%7Erbcp/taia/Freeman1979-centrality.pdf...
#
# =====167 pdfs in output list=====
#
#
# trying to get pdf from https://n.neurology.org/content/neurology/33/11/1444.full.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1540-6261.1997.tb03808.x...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://escholarship.org/content/qt60p6031n/qt60p6031n.pdf?t=p9hliu...
#
# =====168 pdfs in output list=====
#
#
# trying to get pdf from http://www.ajpmonline.org/article/S0749379798000178/pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://genomebiology.biomedcentral.com/counter/pdf/10.1186/gb-2010-11-10-r106...
#
# =====169 pdfs in output list=====
#
#
# trying to get pdf from https://www.nature.com/articles/nmeth.2109.pdf...
#
# =====170 pdfs in output list=====
#
#
# trying to get pdf from https://academic.oup.com/genetics/article-pdf/77/1/71/34393893/genetics0071.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://doi.org/10.1073/pnas.122653799...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://europepmc.org/articles/pmc3146043?pdf=render...
#
# =====171 pdfs in output list=====
#
#
# trying to get pdf from https://karger.com/cpb/article-pdf/35/5/1663/2431330/000373980.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://hal-ens.archives-ouvertes.fr/hal-03907247/document...
#
# =====172 pdfs in output list=====
#
#
# trying to get pdf from https://erj.ersjournals.com/content/erj/26/2/319.full.pdf...
#
# =====173 pdfs in output list=====
#
#
# trying to get pdf from https://arxiv.org/pdf/cond-mat/0606284...
#
# =====174 pdfs in output list=====
#
#
# trying to get pdf from http://link.aps.org/pdf/10.1103/PhysRevLett.58.2059...
#
# =====175 pdfs in output list=====
#
#
# trying to get pdf from http://www.cs.berkeley.edu/~malik/papers/SM-ncut.pdf...
#
# =====176 pdfs in output list=====
#
#
# trying to get pdf from https://doi.org/10.1056/nejmoa1003466...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://direct.mit.edu/jocn/article-pdf/3/1/71/1932018/jocn.1991.3.1.71.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from http://journals.iucr.org/s/issues/2005/04/00/ph5155/ph5155.pdf...
# Could not extract pdf from url. Error: [Errno 2] No such file or directory: '../unilex-transcript/data/PDF/<i>ATHENA</i>,<i>ARTEMIS</i>,<i>HEPHAESTUS</i>:_data_analysis_for_X-ray_absorption_spectroscopy_using<i>IFEFFIT</i>.pdf'
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://europepmc.org/articles/pmc2803035?pdf=render...
#
# =====177 pdfs in output list=====
#
#
# trying to get pdf from https://arxiv.org/pdf/1004.0546...
# Could not extract pdf from url. Error: [Errno 2] No such file or directory: '../unilex-transcript/data/PDF/Atomically_Thin<mml:math_xmlns:mml="http://www.w3.org/1998/Math/MathML"_display="inline"><mml:msub><mml:mi>MoS</mml:mi><mml:mn>2</mml:mn></mml:msub></mml:math>:_A_New_Direct-Gap_Semiconductor.pdf'
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://link.springer.com/content/pdf/10.1007/978-3-319-46448-0_2.pdf...
#
# =====178 pdfs in output list=====
#
#
# trying to get pdf from http://pure.iiasa.ac.at/id/eprint/26/1/RP-73-003.pdf...
#
# =====179 pdfs in output list=====
#
#
# trying to get pdf from https://iopscience.iop.org/article/10.1086/305772/pdf...
#
# =====180 pdfs in output list=====
#
#
# trying to get pdf from https://infoscience.epfl.ch/record/164049/files/NatNano%206%20135%20%282011%29%20Schwierz.pdf...
#
# =====181 pdfs in output list=====
#
#
# trying to get pdf from https://www.science.org/cms/asset/5183a578-57dc-4266-9519-45971027ba5f/pap.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/eurheartj/article-pdf/37/27/2129/23748755/ehw128.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://arxiv.org/pdf/1502.01852...
#
# =====182 pdfs in output list=====
#
#
# trying to get pdf from http://hdl.handle.net/2027/mdp.39015002001249...
#
# =====183 pdfs in output list=====
#
#
# trying to get pdf from https://journals.plos.org/plosone/article/file?id=10.1371/journal.pone.0061217&type=printable...
#
# =====184 pdfs in output list=====
#
#
# trying to get pdf from https://dl.acm.org/doi/pdf/10.1145/219717.219748...
#
# =====185 pdfs in output list=====
#
#
# trying to get pdf from https://arxiv.org/pdf/1611.07004...
#
# =====186 pdfs in output list=====
#
#
# trying to get pdf from https://www.science.org/cms/asset/a46089c6-191e-423e-9438-8b58a6af12af/pap.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://doi.org/10.1016/s0021-9258(18)70226-3...
#
# =====187 pdfs in output list=====
#
#
# trying to get pdf from https://ntrs.nasa.gov/api/citations/19880001113/downloads/19880001113.pdf...
#
# =====188 pdfs in output list=====
#
#
# trying to get pdf from https://academic.oup.com/nar/article-pdf/37/1/1/17059338/gkn923.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from http://journals.iucr.org/j/issues/2003/01/00/os0104/os0104.pdf...
# Could not extract pdf from url. Error: [Errno 2] No such file or directory: '../unilex-transcript/data/PDF/Single-crystal_structure_validation_with_the_program<i>PLATON</i>.pdf'
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from http://www.cra.org/Activities/craw_archive/dmp/awards/2007/Tolbert/self-efficacy.pdf...
#
# =====189 pdfs in output list=====
#
#
# trying to get pdf from https://cancerdiscovery.aacrjournals.org/content/candisc/2/5/401.full.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://arxiv.org/pdf/0803.0476...
#
# =====190 pdfs in output list=====
#
#
# trying to get pdf from https://arxiv.org/pdf/1709.01507...
#
# =====191 pdfs in output list=====
#
#
# trying to get pdf from https://dash.harvard.edu/bitstream/1/30728046/1/w5554.pdf...
#
# =====192 pdfs in output list=====
#
#
# trying to get pdf from https://www.karger.com/Article/Pdf/455014...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://projecteuclid.org/journals/statistical-science/volume-7/issue-4/Inference-from-Iterative-Simulation-Using-Multiple-Sequences/10.1214/ss/1177011136.pdf...
#
# =====193 pdfs in output list=====
#
#
# trying to get pdf from http://clinchem.aaccjnls.org/content/clinchem/55/4/611.full.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://arxiv.org/pdf/cond-mat/0509355...
#
# =====194 pdfs in output list=====
#
#
# trying to get pdf from https://cadernos.cenpec.org.br/cadernos/index.php/cadernos/article/download/293/297...
#
# =====195 pdfs in output list=====
#
#
# trying to get pdf from https://www.karger.com/Article/Pdf/356667...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://academic.oup.com/nar/article-pdf/30/14/3059/9488148/gkf436.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from http://journals.iucr.org/d/issues/2010/01/00/dz5180/dz5180.pdf...
# Could not extract pdf from url. Error: [Errno 2] No such file or directory: '../unilex-transcript/data/PDF/<i>MolProbity</i>:_all-atom_structure_validation_for_macromolecular_crystallography.pdf'
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://doi.org/10.1006/ceps.1999.1020...
#
# =====196 pdfs in output list=====
#
#
# trying to get pdf from https://europepmc.org/articles/pmc3261699?pdf=render...
#
# =====197 pdfs in output list=====
#
#
# trying to get pdf from https://academic.oup.com/nar/article-pdf/18/22/6531/3601793/18-22-6531.pdf...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from https://onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1468-0084.1990.mp52002003.x...
# Could not extract pdf from url. Error: Request GET error. status code not 200
# Error msg:
# could not extract pdf from url
#
# trying to get pdf from http://www.nber.org/papers/w3541.pdf...
#
# =====198 pdfs in output list=====
#
#
# trying to get pdf from https://europepmc.org/articles/pmc2849637?pdf=render...
#
# =====199 pdfs in output list=====
#
#
# trying to get pdf from https://dl.acm.org/doi/pdf/10.1145/331499.331504...
#
# =====200 pdfs in output list=====
#
# ##### FINISHED. 190 papers added to list #####

# %% [markdown]
# # Parse PDF to structured HTML

# %%
import subprocess

# %%
# subprocess.Popen("./pdf2html.py", cwd="/Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript")
# doesn't work (input device is not a TTY?). execute pdf2html.py directly
subprocess.run(
    "./pdf2html.py", cwd="/Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript"
)
# Out:
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/DNA_sequencing_with_chain-terminating_inhibitors /pdf/PDF/DNA_sequencing_with_chain-terminating_inhibitors.pdf DNA_sequencing_with_chain-terminating_inhibitors.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/THE_ADSORPTION_OF_GASES_ON_PLANE_SURFACES_OF_GLASS,_MICA_AND_PLATINUM. /pdf/PDF/THE_ADSORPTION_OF_GASES_ON_PLANE_SURFACES_OF_GLASS,_MICA_AND_PLATINUM..pdf THE_ADSORPTION_OF_GASES_ON_PLANE_SURFACES_OF_GLASS,_MICA_AND_PLATINUM..html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Clinical_course_and_risk_factors_for_mortality_of_adult_inpatients_with_COVID-19_in_Wuhan,_China:_a_retrospective_cohort_study /pdf/PDF/Clinical_course_and_risk_factors_for_mortality_of_adult_inpatients_with_COVID-19_in_Wuhan,_China:_a_retrospective_cohort_study.pdf Clinical_course_and_risk_factors_for_mortality_of_adult_inpatients_with_COVID-19_in_Wuhan,_China:_a_retrospective_cohort_study.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/G*Power_3:_A_flexible_statistical_power_analysis_program_for_the_social,_behavioral,_and_biomedical_sciences /pdf/PDF/G*Power_3:_A_flexible_statistical_power_analysis_program_for_the_social,_behavioral,_and_biomedical_sciences.pdf G*Power_3:_A_flexible_statistical_power_analysis_program_for_the_social,_behavioral,_and_biomedical_sciences.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Scoping_studies:_towards_a_methodological_framework /pdf/PDF/Scoping_studies:_towards_a_methodological_framework.pdf Scoping_studies:_towards_a_methodological_framework.html
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Highly_accurate_protein_structure_prediction_with_AlphaFold /pdf/PDF/Highly_accurate_protein_structure_prediction_with_AlphaFold.pdf Highly_accurate_protein_structure_prediction_with_AlphaFold.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/PRISMA_Extension_for_Scoping_Reviews_(PRISMA-ScR):_Checklist_and_Explanation /pdf/PDF/PRISMA_Extension_for_Scoping_Reviews_(PRISMA-ScR):_Checklist_and_Explanation.pdf PRISMA_Extension_for_Scoping_Reviews_(PRISMA-ScR):_Checklist_and_Explanation.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Rethinking_the_Inception_Architecture_for_Computer_Vision /pdf/PDF/Rethinking_the_Inception_Architecture_for_Computer_Vision.pdf Rethinking_the_Inception_Architecture_for_Computer_Vision.html
# sh: -c: line 0: syntax error near unexpected token `('
# sh: -c: line 0: `docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/PRISMA_Extension_for_Scoping_Reviews_(PRISMA-ScR):_Checklist_and_Explanation /pdf/PDF/PRISMA_Extension_for_Scoping_Reviews_(PRISMA-ScR):_Checklist_and_Explanation.pdf PRISMA_Extension_for_Scoping_Reviews_(PRISMA-ScR):_Checklist_and_Explanation.html'
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/GRADE:_an_emerging_consensus_on_rating_quality_of_evidence_and_strength_of_recommendations /pdf/PDF/GRADE:_an_emerging_consensus_on_rating_quality_of_evidence_and_strength_of_recommendations.pdf GRADE:_an_emerging_consensus_on_rating_quality_of_evidence_and_strength_of_recommendations.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Preferred_Reporting_Items_for_Systematic_Reviews_and_Meta-Analyses:_The_PRISMA_Statement /pdf/PDF/Preferred_Reporting_Items_for_Systematic_Reviews_and_Meta-Analyses:_The_PRISMA_Statement.pdf Preferred_Reporting_Items_for_Systematic_Reviews_and_Meta-Analyses:_The_PRISMA_Statement.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/SPSS_and_SAS_procedures_for_estimating_indirect_effects_in_simple_mediation_models /pdf/PDF/SPSS_and_SAS_procedures_for_estimating_indirect_effects_in_simple_mediation_models.pdf SPSS_and_SAS_procedures_for_estimating_indirect_effects_in_simple_mediation_models.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Inflammation_and_cancer /pdf/PDF/Inflammation_and_cancer.pdf Inflammation_and_cancer.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/A_profile_refinement_method_for_nuclear_and_magnetic_structures /pdf/PDF/A_profile_refinement_method_for_nuclear_and_magnetic_structures.pdf A_profile_refinement_method_for_nuclear_and_magnetic_structures.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/XGBoost /pdf/PDF/XGBoost.pdf XGBoost.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Experimental_observation_of_the_quantum_Hall_effect_and_Berry's_phase_in_graphene /pdf/PDF/Experimental_observation_of_the_quantum_Hall_effect_and_Berry's_phase_in_graphene.pdf Experimental_observation_of_the_quantum_Hall_effect_and_Berry's_phase_in_graphene.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Gene_set_enrichment_analysis:_A_knowledge-based_approach_for_interpreting_genome-wide_expression_profiles /pdf/PDF/Gene_set_enrichment_analysis:_A_knowledge-based_approach_for_interpreting_genome-wide_expression_profiles.pdf Gene_set_enrichment_analysis:_A_knowledge-based_approach_for_interpreting_genome-wide_expression_profiles.html
# sh: -c: line 0: unexpected EOF while looking for matching `''
# sh: -c: line 1: syntax error: unexpected end of file
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Apoptosis:_A_Basic_Biological_Phenomenon_with_Wideranging_Implications_in_Tissue_Kinetics /pdf/PDF/Apoptosis:_A_Basic_Biological_Phenomenon_with_Wideranging_Implications_in_Tissue_Kinetics.pdf Apoptosis:_A_Basic_Biological_Phenomenon_with_Wideranging_Implications_in_Tissue_Kinetics.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Homeostasis_model_assessment:_insulin_resistance_and_?-cell_function_from_fasting_plasma_glucose_and_insulin_concentrations_in_man /pdf/PDF/Homeostasis_model_assessment:_insulin_resistance_and_?-cell_function_from_fasting_plasma_glucose_and_insulin_concentrations_in_man.pdf Homeostasis_model_assessment:_insulin_resistance_and_?-cell_function_from_fasting_plasma_glucose_and_insulin_concentrations_in_man.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Statistical_mechanics_of_complex_networks /pdf/PDF/Statistical_mechanics_of_complex_networks.pdf Statistical_mechanics_of_complex_networks.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/UCSF_Chimera—A_visualization_system_for_exploratory_research_and_analysis /pdf/PDF/UCSF_Chimera—A_visualization_system_for_exploratory_research_and_analysis.pdf UCSF_Chimera—A_visualization_system_for_exploratory_research_and_analysis.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Methods_for_Dietary_Fiber,_Neutral_Detergent_Fiber,_and_Nonstarch_Polysaccharides_in_Relation_to_Animal_Nutrition /pdf/PDF/Methods_for_Dietary_Fiber,_Neutral_Detergent_Fiber,_and_Nonstarch_Polysaccharides_in_Relation_to_Animal_Nutrition.pdf Methods_for_Dietary_Fiber,_Neutral_Detergent_Fiber,_and_Nonstarch_Polysaccharides_in_Relation_to_Animal_Nutrition.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/A_pneumonia_outbreak_associated_with_a_new_coronavirus_of_probable_bat_origin /pdf/PDF/A_pneumonia_outbreak_associated_with_a_new_coronavirus_of_probable_bat_origin.pdf A_pneumonia_outbreak_associated_with_a_new_coronavirus_of_probable_bat_origin.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Prospect_Theory:_An_Analysis_of_Decision_under_Risk /pdf/PDF/Prospect_Theory:_An_Analysis_of_Decision_under_Risk.pdf Prospect_Theory:_An_Analysis_of_Decision_under_Risk.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Transcript_assembly_and_quantification_by_RNA-Seq_reveals_unannotated_transcripts_and_isoform_switching_during_cell_differentiation /pdf/PDF/Transcript_assembly_and_quantification_by_RNA-Seq_reveals_unannotated_transcripts_and_isoform_switching_during_cell_differentiation.pdf Transcript_assembly_and_quantification_by_RNA-Seq_reveals_unannotated_transcripts_and_isoform_switching_during_cell_differentiation.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Raman_Spectrum_of_Graphene_and_Graphene_Layers /pdf/PDF/Raman_Spectrum_of_Graphene_and_Graphene_Layers.pdf Raman_Spectrum_of_Graphene_and_Graphene_Layers.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/A_Guideline_of_Selecting_and_Reporting_Intraclass_Correlation_Coefficients_for_Reliability_Research /pdf/PDF/A_Guideline_of_Selecting_and_Reporting_Intraclass_Correlation_Coefficients_for_Reliability_Research.pdf A_Guideline_of_Selecting_and_Reporting_Intraclass_Correlation_Coefficients_for_Reliability_Research.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Those_Who_Understand:_Knowledge_Growth_in_Teaching /pdf/PDF/Those_Who_Understand:_Knowledge_Growth_in_Teaching.pdf Those_Who_Understand:_Knowledge_Growth_in_Teaching.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/A_New_Equation_to_Estimate_Glomerular_Filtration_Rate /pdf/PDF/A_New_Equation_to_Estimate_Glomerular_Filtration_Rate.pdf A_New_Equation_to_Estimate_Glomerular_Filtration_Rate.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Self-efficacy:_Toward_a_unifying_theory_of_behavioral_change. /pdf/PDF/Self-efficacy:_Toward_a_unifying_theory_of_behavioral_change..pdf Self-efficacy:_Toward_a_unifying_theory_of_behavioral_change..html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/limma_powers_differential_expression_analyses_for_RNA-sequencing_and_microarray_studies /pdf/PDF/limma_powers_differential_expression_analyses_for_RNA-sequencing_and_microarray_studies.pdf limma_powers_differential_expression_analyses_for_RNA-sequencing_and_microarray_studies.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/A_SIMPLE_METHOD_FOR_THE_ISOLATION_AND_PURIFICATION_OF_TOTAL_LIPIDES_FROM_ANIMAL_TISSUES /pdf/PDF/A_SIMPLE_METHOD_FOR_THE_ISOLATION_AND_PURIFICATION_OF_TOTAL_LIPIDES_FROM_ANIMAL_TISSUES.pdf A_SIMPLE_METHOD_FOR_THE_ISOLATION_AND_PURIFICATION_OF_TOTAL_LIPIDES_FROM_ANIMAL_TISSUES.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Estimating_the_Dimension_of_a_Model /pdf/PDF/Estimating_the_Dimension_of_a_Model.pdf Estimating_the_Dimension_of_a_Model.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Moderated_estimation_of_fold_change_and_dispersion_for_RNA-seq_data_with_DESeq2 /pdf/PDF/Moderated_estimation_of_fold_change_and_dispersion_for_RNA-seq_data_with_DESeq2.pdf Moderated_estimation_of_fold_change_and_dispersion_for_RNA-seq_data_with_DESeq2.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Image-to-Image_Translation_with_Conditional_Adversarial_Networks /pdf/PDF/Image-to-Image_Translation_with_Conditional_Adversarial_Networks.pdf Image-to-Image_Translation_with_Conditional_Adversarial_Networks.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Structure_validation_in_chemical_crystallography /pdf/PDF/Structure_validation_in_chemical_crystallography.pdf Structure_validation_in_chemical_crystallography.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Materials_for_electrochemical_capacitors /pdf/PDF/Materials_for_electrochemical_capacitors.pdf Materials_for_electrochemical_capacitors.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Self-Consistent_Equations_Including_Exchange_and_Correlation_Effects /pdf/PDF/Self-Consistent_Equations_Including_Exchange_and_Correlation_Effects.pdf Self-Consistent_Equations_Including_Exchange_and_Correlation_Effects.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Bootstrap_Methods:_Another_Look_at_the_Jackknife /pdf/PDF/Bootstrap_Methods:_Another_Look_at_the_Jackknife.pdf Bootstrap_Methods:_Another_Look_at_the_Jackknife.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Electrophoretic_transfer_of_proteins_from_polyacrylamide_gels_to_nitrocellulose_sheets:_procedure_and_some_applications. /pdf/PDF/Electrophoretic_transfer_of_proteins_from_polyacrylamide_gels_to_nitrocellulose_sheets:_procedure_and_some_applications..pdf Electrophoretic_transfer_of_proteins_from_polyacrylamide_gels_to_nitrocellulose_sheets:_procedure_and_some_applications..html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/MOLSCRIPT:_a_program_to_produce_both_detailed_and_schematic_plots_of_protein_structures /pdf/PDF/MOLSCRIPT:_a_program_to_produce_both_detailed_and_schematic_plots_of_protein_structures.pdf MOLSCRIPT:_a_program_to_produce_both_detailed_and_schematic_plots_of_protein_structures.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/A_Contribution_to_the_Empirics_of_Economic_Growth /pdf/PDF/A_Contribution_to_the_Empirics_of_Economic_Growth.pdf A_Contribution_to_the_Empirics_of_Economic_Growth.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/The_CES-D_Scale /pdf/PDF/The_CES-D_Scale.pdf The_CES-D_Scale.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Measurements_of_Ω_and_Λ_from_42_High‐Redshift_Supernovae /pdf/PDF/Measurements_of_Ω_and_Λ_from_42_High‐Redshift_Supernovae.pdf Measurements_of_Ω_and_Λ_from_42_High‐Redshift_Supernovae.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/The_electronic_properties_of_graphene /pdf/PDF/The_electronic_properties_of_graphene.pdf The_electronic_properties_of_graphene.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Microsoft_COCO:_Common_Objects_in_Context /pdf/PDF/Microsoft_COCO:_Common_Objects_in_Context.pdf Microsoft_COCO:_Common_Objects_in_Context.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/QUANTUM_ESPRESSO:_a_modular_and_open-source_software_project_for_quantum_simulations_of_materials /pdf/PDF/QUANTUM_ESPRESSO:_a_modular_and_open-source_software_project_for_quantum_simulations_of_materials.pdf QUANTUM_ESPRESSO:_a_modular_and_open-source_software_project_for_quantum_simulations_of_materials.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Gene_Ontology:_tool_for_the_unification_of_biology /pdf/PDF/Gene_Ontology:_tool_for_the_unification_of_biology.pdf Gene_Ontology:_tool_for_the_unification_of_biology.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/U-Net:_Convolutional_Networks_for_Biomedical_Image_Segmentation /pdf/PDF/U-Net:_Convolutional_Networks_for_Biomedical_Image_Segmentation.pdf U-Net:_Convolutional_Networks_for_Biomedical_Image_Segmentation.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Standardisation_of_spirometry /pdf/PDF/Standardisation_of_spirometry.pdf Standardisation_of_spirometry.html
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/A_unified_formulation_of_the_constant_temperature_molecular_dynamics_methods /pdf/PDF/A_unified_formulation_of_the_constant_temperature_molecular_dynamics_methods.pdf A_unified_formulation_of_the_constant_temperature_molecular_dynamics_methods.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/The_Elements_of_Statistical_Learning /pdf/PDF/The_Elements_of_Statistical_Learning.pdf The_Elements_of_Statistical_Learning.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Situated_Learning:_Legitimate_Peripheral_Participation. /pdf/PDF/Situated_Learning:_Legitimate_Peripheral_Participation..pdf Situated_Learning:_Legitimate_Peripheral_Participation..html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/phyloseq:_An_R_Package_for_Reproducible_Interactive_Analysis_and_Graphics_of_Microbiome_Census_Data /pdf/PDF/phyloseq:_An_R_Package_for_Reproducible_Interactive_Analysis_and_Graphics_of_Microbiome_Census_Data.pdf phyloseq:_An_R_Package_for_Reproducible_Interactive_Analysis_and_Graphics_of_Microbiome_Census_Data.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Electronics_and_optoelectronics_of_two-dimensional_transition_metal_dichalcogenides /pdf/PDF/Electronics_and_optoelectronics_of_two-dimensional_transition_metal_dichalcogenides.pdf Electronics_and_optoelectronics_of_two-dimensional_transition_metal_dichalcogenides.html
#
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/The_PRISMA_statement_for_reporting_systematic_reviews_and_meta-analyses_of_studies_that_evaluate_healthcare_interventions:_explanation_and_elaboration /pdf/PDF/The_PRISMA_statement_for_reporting_systematic_reviews_and_meta-analyses_of_studies_that_evaluate_healthcare_interventions:_explanation_and_elaboration.pdf The_PRISMA_statement_for_reporting_systematic_reviews_and_meta-analyses_of_studies_that_evaluate_healthcare_interventions:_explanation_and_elaboration.htmldocker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Centrality_in_social_networks_conceptual_clarification /pdf/PDF/Centrality_in_social_networks_conceptual_clarification.pdf Centrality_in_social_networks_conceptual_clarification.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Common_risk_factors_in_the_returns_on_stocks_and_bonds /pdf/PDF/Common_risk_factors_in_the_returns_on_stocks_and_bonds.pdf Common_risk_factors_in_the_returns_on_stocks_and_bonds.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/RAxML-VI-HPC:_maximum_likelihood-based_phylogenetic_analyses_with_thousands_of_taxa_and_mixed_models /pdf/PDF/RAxML-VI-HPC:_maximum_likelihood-based_phylogenetic_analyses_with_thousands_of_taxa_and_mixed_models.pdf RAxML-VI-HPC:_maximum_likelihood-based_phylogenetic_analyses_with_thousands_of_taxa_and_mixed_models.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Atomic_Force_Microscope /pdf/PDF/Atomic_Force_Microscope.pdf Atomic_Force_Microscope.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/A_Decision-Theoretic_Generalization_of_On-Line_Learning_and_an_Application_to_Boosting /pdf/PDF/A_Decision-Theoretic_Generalization_of_On-Line_Learning_and_an_Application_to_Boosting.pdf A_Decision-Theoretic_Generalization_of_On-Line_Learning_and_an_Application_to_Boosting.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/MapReduce /pdf/PDF/MapReduce.pdf MapReduce.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Fast,_scalable_generation_of_high‐quality_protein_multiple_sequence_alignments_using_Clustal_Omega /pdf/PDF/Fast,_scalable_generation_of_high‐quality_protein_multiple_sequence_alignments_using_Clustal_Omega.pdf Fast,_scalable_generation_of_high‐quality_protein_multiple_sequence_alignments_using_Clustal_Omega.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Statistical_power_analyses_using_G*Power_3.1:_Tests_for_correlation_and_regression_analyses /pdf/PDF/Statistical_power_analyses_using_G*Power_3.1:_Tests_for_correlation_and_regression_analyses.pdf Statistical_power_analyses_using_G*Power_3.1:_Tests_for_correlation_and_regression_analyses.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Molecular_portraits_of_human_breast_tumours /pdf/PDF/Molecular_portraits_of_human_breast_tumours.pdf Molecular_portraits_of_human_breast_tumours.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Learning_Phrase_Representations_using_RNN_Encoder–Decoder_for_Statistical_Machine_Translation /pdf/PDF/Learning_Phrase_Representations_using_RNN_Encoder–Decoder_for_Statistical_Machine_Translation.pdf Learning_Phrase_Representations_using_RNN_Encoder–Decoder_for_Statistical_Machine_Translation.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Histograms_of_Oriented_Gradients_for_Human_Detection /pdf/PDF/Histograms_of_Oriented_Gradients_for_Human_Detection.pdf Histograms_of_Oriented_Gradients_for_Human_Detection.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Electric_Field_Effect_in_Atomically_Thin_Carbon_Films /pdf/PDF/Electric_Field_Effect_in_Atomically_Thin_Carbon_Films.pdf Electric_Field_Effect_in_Atomically_Thin_Carbon_Films.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/The_Reliability_of_Molecular_Weight_Determinations_by_Dodecyl_Sulfate-Polyacrylamide_Gel_Electrophoresis /pdf/PDF/The_Reliability_of_Molecular_Weight_Determinations_by_Dodecyl_Sulfate-Polyacrylamide_Gel_Electrophoresis.pdf The_Reliability_of_Molecular_Weight_Determinations_by_Dodecyl_Sulfate-Polyacrylamide_Gel_Electrophoresis.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Cutadapt_removes_adapter_sequences_from_high-throughput_sequencing_reads /pdf/PDF/Cutadapt_removes_adapter_sequences_from_high-throughput_sequencing_reads.pdf Cutadapt_removes_adapter_sequences_from_high-throughput_sequencing_reads.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Geant4—a_simulation_toolkit /pdf/PDF/Geant4—a_simulation_toolkit.pdf Geant4—a_simulation_toolkit.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Knowledge_and_Teaching:Foundations_of_the_New_Reform /pdf/PDF/Knowledge_and_Teaching:Foundations_of_the_New_Reform.pdf Knowledge_and_Teaching:Foundations_of_the_New_Reform.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/DeepLab:_Semantic_Image_Segmentation_with_Deep_Convolutional_Nets,_Atrous_Convolution,_and_Fully_Connected_CRFs /pdf/PDF/DeepLab:_Semantic_Image_Segmentation_with_Deep_Convolutional_Nets,_Atrous_Convolution,_and_Fully_Connected_CRFs.pdf DeepLab:_Semantic_Image_Segmentation_with_Deep_Convolutional_Nets,_Atrous_Convolution,_and_Fully_Connected_CRFs.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Cluster_analysis_and_display_of_genome-wide_expression_patterns /pdf/PDF/Cluster_analysis_and_display_of_genome-wide_expression_patterns.pdf Cluster_analysis_and_display_of_genome-wide_expression_patterns.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/AutoDock4_and_AutoDockTools4:_Automated_docking_with_selective_receptor_flexibility /pdf/PDF/AutoDock4_and_AutoDockTools4:_Automated_docking_with_selective_receptor_flexibility.pdf AutoDock4_and_AutoDockTools4:_Automated_docking_with_selective_receptor_flexibility.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Cytoscape:_A_Software_Environment_for_Integrated_Models_of_Biomolecular_Interaction_Networks /pdf/PDF/Cytoscape:_A_Software_Environment_for_Integrated_Models_of_Biomolecular_Interaction_Networks.pdf Cytoscape:_A_Software_Environment_for_Integrated_Models_of_Biomolecular_Interaction_Networks.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/NIH_Image_to_ImageJ:_25_years_of_image_analysis /pdf/PDF/NIH_Image_to_ImageJ:_25_years_of_image_analysis.pdf NIH_Image_to_ImageJ:_25_years_of_image_analysis.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Studies_of_interference_in_serial_verbal_reactions. /pdf/PDF/Studies_of_interference_in_serial_verbal_reactions..pdf Studies_of_interference_in_serial_verbal_reactions..html
#
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Coefficient_alpha_and_the_internal_structure_of_tests /pdf/PDF/Coefficient_alpha_and_the_internal_structure_of_tests.pdf Coefficient_alpha_and_the_internal_structure_of_tests.html
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Two-dimensional_gas_of_massless_Dirac_fermions_in_graphene /pdf/PDF/Two-dimensional_gas_of_massless_Dirac_fermions_in_graphene.pdf Two-dimensional_gas_of_massless_Dirac_fermions_in_graphene.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Squeeze-and-Excitation_Networks /pdf/PDF/Squeeze-and-Excitation_Networks.pdf Squeeze-and-Excitation_Networks.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Initial_sequencing_and_analysis_of_the_human_genome /pdf/PDF/Initial_sequencing_and_analysis_of_the_human_genome.pdf Initial_sequencing_and_analysis_of_the_human_genome.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/High_resolution_two-dimensional_electrophoresis_of_proteins. /pdf/PDF/High_resolution_two-dimensional_electrophoresis_of_proteins..pdf High_resolution_two-dimensional_electrophoresis_of_proteins..html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Fast_unfolding_of_communities_in_large_networks /pdf/PDF/Fast_unfolding_of_communities_in_large_networks.pdf Fast_unfolding_of_communities_in_large_networks.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Standards_and_guidelines_for_the_interpretation_of_sequence_variants:_a_joint_consensus_recommendation_of_the_American_College_of_Medical_Genetics_and_Genomics_and_the_Association_for_Molecular_Pathology /pdf/PDF/Standards_and_guidelines_for_the_interpretation_of_sequence_variants:_a_joint_consensus_recommendation_of_the_American_College_of_Medical_Genetics_and_Genomics_and_the_Association_for_Molecular_Pathology.pdf Standards_and_guidelines_for_the_interpretation_of_sequence_variants:_a_joint_consensus_recommendation_of_the_American_College_of_Medical_Genetics_and_Genomics_and_the_Association_for_Molecular_Pathology.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Data_clustering /pdf/PDF/Data_clustering.pdf Data_clustering.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Single-layer_MoS2_transistors /pdf/PDF/Single-layer_MoS2_transistors.pdf Single-layer_MoS2_transistors.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/CLUSTAL_W:_improving_the_sensitivity_of_progressive_multiple_sequence_alignment_through_sequence_weighting,_position-specific_gap_penalties_and_weight_matrix_choice /pdf/PDF/CLUSTAL_W:_improving_the_sensitivity_of_progressive_multiple_sequence_alignment_through_sequence_weighting,_position-specific_gap_penalties_and_weight_matrix_choice.pdf CLUSTAL_W:_improving_the_sensitivity_of_progressive_multiple_sequence_alignment_through_sequence_weighting,_position-specific_gap_penalties_and_weight_matrix_choice.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Fronts_propagating_with_curvature-dependent_speed:_Algorithms_based_on_Hamilton-Jacobi_formulations /pdf/PDF/Fronts_propagating_with_curvature-dependent_speed:_Algorithms_based_on_Hamilton-Jacobi_formulations.pdf Fronts_propagating_with_curvature-dependent_speed:_Algorithms_based_on_Hamilton-Jacobi_formulations.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Delving_Deep_into_Rectifiers:_Surpassing_Human-Level_Performance_on_ImageNet_Classification /pdf/PDF/Delving_Deep_into_Rectifiers:_Surpassing_Human-Level_Performance_on_ImageNet_Classification.pdf Delving_Deep_into_Rectifiers:_Surpassing_Human-Level_Performance_on_ImageNet_Classification.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Greedy_function_approximation:_A_gradient_boosting_machine. /pdf/PDF/Greedy_function_approximation:_A_gradient_boosting_machine..pdf Greedy_function_approximation:_A_gradient_boosting_machine..html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Evidence_based_medicine:_what_it_is_and_what_it_isn't /pdf/PDF/Evidence_based_medicine:_what_it_is_and_what_it_isn't.pdf Evidence_based_medicine:_what_it_is_and_what_it_isn't.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Establishing_a_standard_definition_for_child_overweight_and_obesity_worldwide:_international_survey /pdf/PDF/Establishing_a_standard_definition_for_child_overweight_and_obesity_worldwide:_international_survey.pdf Establishing_a_standard_definition_for_child_overweight_and_obesity_worldwide:_international_survey.html
# sh: -c: line 0: unexpected EOF while looking for matching `''
# sh: -c: line 1: syntax error: unexpected end of file
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Glutathione_S-Transferases /pdf/PDF/Glutathione_S-Transferases.pdf Glutathione_S-Transferases.html
#
# ...
# sh: -c: line 0: unexpected EOF while looking for matching `''
# sh: -c: line 1: syntax error: unexpected end of file
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Statistical_principles_in_experimental_design. /pdf/PDF/Statistical_principles_in_experimental_design..pdf Statistical_principles_in_experimental_design..html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Differential_expression_analysis_for_sequence_count_data /pdf/PDF/Differential_expression_analysis_for_sequence_count_data.pdf Differential_expression_analysis_for_sequence_count_data.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/On_Information_and_Sufficiency /pdf/PDF/On_Information_and_Sufficiency.pdf On_Information_and_Sufficiency.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/THE_COLORIMETRIC_DETERMINATION_OF_PHOSPHORUS /pdf/PDF/THE_COLORIMETRIC_DETERMINATION_OF_PHOSPHORUS.pdf THE_COLORIMETRIC_DETERMINATION_OF_PHOSPHORUS.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Research_electronic_data_capture_(REDCap)—A_metadata-driven_methodology_and_workflow_process_for_providing_translational_research_informatics_support /pdf/PDF/Research_electronic_data_capture_(REDCap)—A_metadata-driven_methodology_and_workflow_process_for_providing_translational_research_informatics_support.pdf Research_electronic_data_capture_(REDCap)—A_metadata-driven_methodology_and_workflow_process_for_providing_translational_research_informatics_support.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Resilience_and_Stability_of_Ecological_Systems /pdf/PDF/Resilience_and_Stability_of_Ecological_Systems.pdf Resilience_and_Stability_of_Ecological_Systems.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/A_Simple,_Positive_Semi-Definite,_Heteroskedasticity_and_Autocorrelation_Consistent_Covariance_Matrix /pdf/PDF/A_Simple,_Positive_Semi-Definite,_Heteroskedasticity_and_Autocorrelation_Consistent_Covariance_Matrix.pdf A_Simple,_Positive_Semi-Definite,_Heteroskedasticity_and_Autocorrelation_Consistent_Covariance_Matrix.html
# sh: -c: line 0: syntax error near unexpected token `('
# sh: -c: line 0: `docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Research_electronic_data_capture_(REDCap)—A_metadata-driven_methodology_and_workflow_process_for_providing_translational_research_informatics_support /pdf/PDF/Research_electronic_data_capture_(REDCap)—A_metadata-driven_methodology_and_workflow_process_for_providing_translational_research_informatics_support.pdf Research_electronic_data_capture_(REDCap)—A_metadata-driven_methodology_and_workflow_process_for_providing_translational_research_informatics_support.html'
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/RSEM:_accurate_transcript_quantification_from_RNA-Seq_data_with_or_without_a_reference_genome /pdf/PDF/RSEM:_accurate_transcript_quantification_from_RNA-Seq_data_with_or_without_a_reference_genome.pdf RSEM:_accurate_transcript_quantification_from_RNA-Seq_data_with_or_without_a_reference_genome.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/SPAdes:_A_New_Genome_Assembly_Algorithm_and_Its_Applications_to_Single-Cell_Sequencing /pdf/PDF/SPAdes:_A_New_Genome_Assembly_Algorithm_and_Its_Applications_to_Single-Cell_Sequencing.pdf SPAdes:_A_New_Genome_Assembly_Algorithm_and_Its_Applications_to_Single-Cell_Sequencing.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Going_deeper_with_convolutions /pdf/PDF/Going_deeper_with_convolutions.pdf Going_deeper_with_convolutions.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Random_sample_consensus /pdf/PDF/Random_sample_consensus.pdf Random_sample_consensus.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Neural_networks_and_physical_systems_with_emergent_collective_computational_abilities. /pdf/PDF/Neural_networks_and_physical_systems_with_emergent_collective_computational_abilities..pdf Neural_networks_and_physical_systems_with_emergent_collective_computational_abilities..html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Clinical_features_of_patients_infected_with_2019_novel_coronavirus_in_Wuhan,_China /pdf/PDF/Clinical_features_of_patients_infected_with_2019_novel_coronavirus_in_Wuhan,_China.pdf Clinical_features_of_patients_infected_with_2019_novel_coronavirus_in_Wuhan,_China.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Generalized_autoregressive_conditional_heteroskedasticity /pdf/PDF/Generalized_autoregressive_conditional_heteroskedasticity.pdf Generalized_autoregressive_conditional_heteroskedasticity.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Bias_in_meta-analysis_detected_by_a_simple,_graphical_test /pdf/PDF/Bias_in_meta-analysis_detected_by_a_simple,_graphical_test.pdf Bias_in_meta-analysis_detected_by_a_simple,_graphical_test.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Inhomogeneous_Electron_Gas /pdf/PDF/Inhomogeneous_Electron_Gas.pdf Inhomogeneous_Electron_Gas.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/A_new_criterion_for_assessing_discriminant_validity_in_variance-based_structural_equation_modeling /pdf/PDF/A_new_criterion_for_assessing_discriminant_validity_in_variance-based_structural_equation_modeling.pdf A_new_criterion_for_assessing_discriminant_validity_in_variance-based_structural_equation_modeling.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/The_Nature_of_Statistical_Learning_Theory /pdf/PDF/The_Nature_of_Statistical_Learning_Theory.pdf The_Nature_of_Statistical_Learning_Theory.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Molecular_dynamics_with_coupling_to_an_external_bath /pdf/PDF/Molecular_dynamics_with_coupling_to_an_external_bath.pdf Molecular_dynamics_with_coupling_to_an_external_bath.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Feature_Pyramid_Networks_for_Object_Detection /pdf/PDF/Feature_Pyramid_Networks_for_Object_Detection.pdf Feature_Pyramid_Networks_for_Object_Detection.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/A_Survey_of_Corporate_Governance /pdf/PDF/A_Survey_of_Corporate_Governance.pdf A_Survey_of_Corporate_Governance.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Measuring_inconsistency_in_meta-analyses /pdf/PDF/Measuring_inconsistency_in_meta-analyses.pdf Measuring_inconsistency_in_meta-analyses.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/WGCNA:_an_R_package_for_weighted_correlation_network_analysis /pdf/PDF/WGCNA:_an_R_package_for_weighted_correlation_network_analysis.pdf WGCNA:_an_R_package_for_weighted_correlation_network_analysis.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Focal_Loss_for_Dense_Object_Detection /pdf/PDF/Focal_Loss_for_Dense_Object_Detection.pdf Focal_Loss_for_Dense_Object_Detection.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Support-vector_networks /pdf/PDF/Support-vector_networks.pdf Support-vector_networks.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Note_on_an_Approximation_Treatment_for_Many-Electron_Systems /pdf/PDF/Note_on_an_Approximation_Treatment_for_Many-Electron_Systems.pdf Note_on_an_Approximation_Treatment_for_Many-Electron_Systems.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Normalized_cuts_and_image_segmentation /pdf/PDF/Normalized_cuts_and_image_segmentation.pdf Normalized_cuts_and_image_segmentation.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Gradient-based_learning_applied_to_document_recognition /pdf/PDF/Gradient-based_learning_applied_to_document_recognition.pdf Gradient-based_learning_applied_to_document_recognition.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Inhibited_Spontaneous_Emission_in_Solid-State_Physics_and_Electronics /pdf/PDF/Inhibited_Spontaneous_Emission_in_Solid-State_Physics_and_Electronics.pdf Inhibited_Spontaneous_Emission_in_Solid-State_Physics_and_Electronics.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Emergence_of_Scaling_in_Random_Networks /pdf/PDF/Emergence_of_Scaling_in_Random_Networks.pdf Emergence_of_Scaling_in_Random_Networks.html
#
# docker run -ti --rm -v /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data:/pdf -w /pdf pdf2htmlex/pdf2htmlex:0.18.8.rc2-master-20200820-ubuntu-20.04-x86_64 --embed-external-font 0  --process-nontext 0 --embed cfijo --dest-dir /pdf/HTML/Full-length_transcriptome_assembly_from_RNA-Seq_data_without_a_reference_genome /pdf/PDF/Full-length_transcriptome_assembly_from_RNA-Seq_data_without_a_reference_genome.pdf Full-length_transcriptome_assembly_from_RNA-Seq_data_without_a_reference_genome.html
# the input device is not a TTY
# the input device is not a TTY
# the input device is not a TTY
# CompletedProcess(args='./pdf2html.py', returncode=0)

# %%
subprocess.run(
    "./transcript.py", cwd="/Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript"
)
# Out:
# Loading fonts from: /path/to/truetype/fonts/
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/A_Simple,_Positive_Semi-Definite,_Heteroskedasticity_and_Autocorrelation_Consistent_Covariance_Matrix/A_Simple,_Positive_Semi-Definite,_Heteroskedasticity_and_Autocorrelation_Consistent_Covariance_Matrix.html
# list index out of range
# Traceback (most recent call last):
#   File "/Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/./transcript.py", line 427, in batch_process
#     semanticize(path)
#   File "/Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/./transcript.py", line 319, in semanticize
#     h_levels = heading_levels(dom, dimensions)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/./transcript.py", line 276, in heading_levels
#     prevalent_fs = top_stats[0][-1]
#                    ~~~~~~~~~^^^
# IndexError: list index out of range
#
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/SSD:_Single_Shot_MultiBox_Detector/SSD:_Single_Shot_MultiBox_Detector.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/DeepLab:_Semantic_Image_Segmentation_with_Deep_Convolutional_Nets,_Atrous_Convolution,_and_Fully_Connected_CRFs/DeepLab:_Semantic_Image_Segmentation_with_Deep_Convolutional_Nets,_Atrous_Convolution,_and_Fully_Connected_CRFs.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/The_Elements_of_Statistical_Learning/The_Elements_of_Statistical_Learning.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Normalized_cuts_and_image_segmentation/Normalized_cuts_and_image_segmentation.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Bias_in_meta-analysis_detected_by_a_simple,_graphical_test/Bias_in_meta-analysis_detected_by_a_simple,_graphical_test.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Support-vector_networks/Support-vector_networks.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Atomic_Force_Microscope/Atomic_Force_Microscope.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Going_deeper_with_convolutions/Going_deeper_with_convolutions.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Inflammation_and_cancer/Inflammation_and_cancer.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/A_unified_formulation_of_the_constant_temperature_molecular_dynamics_methods/A_unified_formulation_of_the_constant_temperature_molecular_dynamics_methods.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Note_on_an_Approximation_Treatment_for_Many-Electron_Systems/Note_on_an_Approximation_Treatment_for_Many-Electron_Systems.html
# list index out of range
# Traceback (most recent call last):
#   File "/Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/./transcript.py", line 427, in batch_process
#     semanticize(path)
#   File "/Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/./transcript.py", line 319, in semanticize
#     h_levels = heading_levels(dom, dimensions)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/./transcript.py", line 276, in heading_levels
#     prevalent_fs = top_stats[0][-1]
#                    ~~~~~~~~~^^^
# IndexError: list index out of range
#
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Using_thematic_analysis_in_psychology/Using_thematic_analysis_in_psychology.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Situated_Learning:_Legitimate_Peripheral_Participation./Situated_Learning:_Legitimate_Peripheral_Participation..html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Inference_from_Iterative_Simulation_Using_Multiple_Sequences/Inference_from_Iterative_Simulation_Using_Multiple_Sequences.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Fast_Parallel_Algorithms_for_Short-Range_Molecular_Dynamics/Fast_Parallel_Algorithms_for_Short-Range_Molecular_Dynamics.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/A_New_Equation_to_Estimate_Glomerular_Filtration_Rate/A_New_Equation_to_Estimate_Glomerular_Filtration_Rate.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Neural_networks_and_physical_systems_with_emergent_collective_computational_abilities./Neural_networks_and_physical_systems_with_emergent_collective_computational_abilities..html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Densely_Connected_Convolutional_Networks/Densely_Connected_Convolutional_Networks.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/SPSS_and_SAS_procedures_for_estimating_indirect_effects_in_simple_mediation_models/SPSS_and_SAS_procedures_for_estimating_indirect_effects_in_simple_mediation_models.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/THE_ADSORPTION_OF_GASES_ON_PLANE_SURFACES_OF_GLASS,_MICA_AND_PLATINUM./THE_ADSORPTION_OF_GASES_ON_PLANE_SURFACES_OF_GLASS,_MICA_AND_PLATINUM..html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Homeostasis_model_assessment:_insulin_resistance_and_?-cell_function_from_fasting_plasma_glucose_and_insulin_concentrations_in_man/Homeostasis_model_assessment:_insulin_resistance_and_?-cell_function_from_fasting_plasma_glucose_and_insulin_concentrations_in_man.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/SPAdes:_A_New_Genome_Assembly_Algorithm_and_Its_Applications_to_Single-Cell_Sequencing/SPAdes:_A_New_Genome_Assembly_Algorithm_and_Its_Applications_to_Single-Cell_Sequencing.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Generalized_autoregressive_conditional_heteroskedasticity/Generalized_autoregressive_conditional_heteroskedasticity.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Statistical_mechanics_of_complex_networks/Statistical_mechanics_of_complex_networks.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Establishing_a_standard_definition_for_child_overweight_and_obesity_worldwide:_international_survey/Establishing_a_standard_definition_for_child_overweight_and_obesity_worldwide:_international_survey.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/QUANTUM_ESPRESSO:_a_modular_and_open-source_software_project_for_quantum_simulations_of_materials/QUANTUM_ESPRESSO:_a_modular_and_open-source_software_project_for_quantum_simulations_of_materials.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Single-layer_MoS2_transistors/Single-layer_MoS2_transistors.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/A_pneumonia_outbreak_associated_with_a_new_coronavirus_of_probable_bat_origin/A_pneumonia_outbreak_associated_with_a_new_coronavirus_of_probable_bat_origin.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/ImageNet_classification_with_deep_convolutional_neural_networks/ImageNet_classification_with_deep_convolutional_neural_networks.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Faster_R-CNN:_Towards_Real-Time_Object_Detection_with_Region_Proposal_Networks/Faster_R-CNN:_Towards_Real-Time_Object_Detection_with_Region_Proposal_Networks.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Bagging_predictors/Bagging_predictors.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Image-to-Image_Translation_with_Conditional_Adversarial_Networks/Image-to-Image_Translation_with_Conditional_Adversarial_Networks.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Fiji:_an_open-source_platform_for_biological-image_analysis/Fiji:_an_open-source_platform_for_biological-image_analysis.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/The_Genome_Analysis_Toolkit:_A_MapReduce_framework_for_analyzing_next-generation_DNA_sequencing_data/The_Genome_Analysis_Toolkit:_A_MapReduce_framework_for_analyzing_next-generation_DNA_sequencing_data.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Inhibited_Spontaneous_Emission_in_Solid-State_Physics_and_Electronics/Inhibited_Spontaneous_Emission_in_Solid-State_Physics_and_Electronics.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Moderated_estimation_of_fold_change_and_dispersion_for_RNA-seq_data_with_DESeq2/Moderated_estimation_of_fold_change_and_dispersion_for_RNA-seq_data_with_DESeq2.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Atoms,_molecules,_solids,_and_surfaces:_Applications_of_the_generalized_gradient_approximation_for_exchange_and_correlation/Atoms,_molecules,_solids,_and_surfaces:_Applications_of_the_generalized_gradient_approximation_for_exchange_and_correlation.html
# list index out of range
# Traceback (most recent call last):
#   File "/Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/./transcript.py", line 427, in batch_process
#     semanticize(path)
#   File "/Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/./transcript.py", line 319, in semanticize
#     h_levels = heading_levels(dom, dimensions)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/./transcript.py", line 276, in heading_levels
#     prevalent_fs = top_stats[0][-1]
#                    ~~~~~~~~~^^^
# IndexError: list index out of range
#
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Data_clustering/Data_clustering.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Standardisation_of_spirometry/Standardisation_of_spirometry.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Feature_Pyramid_Networks_for_Object_Detection/Feature_Pyramid_Networks_for_Object_Detection.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Electronics_and_optoelectronics_of_two-dimensional_transition_metal_dichalcogenides/Electronics_and_optoelectronics_of_two-dimensional_transition_metal_dichalcogenides.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Those_Who_Understand:_Knowledge_Growth_in_Teaching/Those_Who_Understand:_Knowledge_Growth_in_Teaching.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/UCSF_Chimera—A_visualization_system_for_exploratory_research_and_analysis/UCSF_Chimera—A_visualization_system_for_exploratory_research_and_analysis.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/XGBoost/XGBoost.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Geant4—a_simulation_toolkit/Geant4—a_simulation_toolkit.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/GROMACS_4:_Algorithms_for_Highly_Efficient,_Load-Balanced,_and_Scalable_Molecular_Simulation/GROMACS_4:_Algorithms_for_Highly_Efficient,_Load-Balanced,_and_Scalable_Molecular_Simulation.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/The_PRISMA_Statement_for_Reporting_Systematic_Reviews_and_Meta-Analyses_of_Studies_That_Evaluate_Health_Care_Interventions:_Explanation_and_Elaboration/The_PRISMA_Statement_for_Reporting_Systematic_Reviews_and_Meta-Analyses_of_Studies_That_Evaluate_Health_Care_Interventions:_Explanation_and_Elaboration.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/An_introduction_to_ROC_analysis/An_introduction_to_ROC_analysis.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Molecular_dynamics_with_coupling_to_an_external_bath/Molecular_dynamics_with_coupling_to_an_external_bath.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/A_global_reference_for_human_genetic_variation/A_global_reference_for_human_genetic_variation.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/limma_powers_differential_expression_analyses_for_RNA-sequencing_and_microarray_studies/limma_powers_differential_expression_analyses_for_RNA-sequencing_and_microarray_studies.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Initial_sequencing_and_analysis_of_the_human_genome/Initial_sequencing_and_analysis_of_the_human_genome.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/An_integrated_encyclopedia_of_DNA_elements_in_the_human_genome/An_integrated_encyclopedia_of_DNA_elements_in_the_human_genome.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Ultrafast_and_memory-efficient_alignment_of_short_DNA_sequences_to_the_human_genome/Ultrafast_and_memory-efficient_alignment_of_short_DNA_sequences_to_the_human_genome.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Development_of_the_Colle-Salvetti_correlation-energy_formula_into_a_functional_of_the_electron_density/Development_of_the_Colle-Salvetti_correlation-energy_formula_into_a_functional_of_the_electron_density.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/A_fast_and_elitist_multiobjective_genetic_algorithm:_NSGA-II/A_fast_and_elitist_multiobjective_genetic_algorithm:_NSGA-II.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Materials_for_electrochemical_capacitors/Materials_for_electrochemical_capacitors.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Adam:_A_Method_for_Stochastic_Optimization/Adam:_A_Method_for_Stochastic_Optimization.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Cutadapt_removes_adapter_sequences_from_high-throughput_sequencing_reads/Cutadapt_removes_adapter_sequences_from_high-throughput_sequencing_reads.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/SciPy_1.0:_fundamental_algorithms_for_scientific_computing_in_Python/SciPy_1.0:_fundamental_algorithms_for_scientific_computing_in_Python.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Scoping_studies:_towards_a_methodological_framework/Scoping_studies:_towards_a_methodological_framework.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Self-interaction_correction_to_density-functional_approximations_for_many-electron_systems/Self-interaction_correction_to_density-functional_approximations_for_many-electron_systems.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/The_Structure_and_Function_of_Complex_Networks/The_Structure_and_Function_of_Complex_Networks.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/The_moderator–mediator_variable_distinction_in_social_psychological_research:_Conceptual,_strategic,_and_statistical_considerations./The_moderator–mediator_variable_distinction_in_social_psychological_research:_Conceptual,_strategic,_and_statistical_considerations..html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Two-dimensional_gas_of_massless_Dirac_fermions_in_graphene/Two-dimensional_gas_of_massless_Dirac_fermions_in_graphene.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Inhomogeneous_Electron_Gas/Inhomogeneous_Electron_Gas.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Initial_conditions_and_moment_restrictions_in_dynamic_panel_data_models/Initial_conditions_and_moment_restrictions_in_dynamic_panel_data_models.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/NIH_Image_to_ImageJ:_25_years_of_image_analysis/NIH_Image_to_ImageJ:_25_years_of_image_analysis.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/BLEU/BLEU.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Rethinking_the_Inception_Architecture_for_Computer_Vision/Rethinking_the_Inception_Architecture_for_Computer_Vision.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/A_Guideline_of_Selecting_and_Reporting_Intraclass_Correlation_Coefficients_for_Reliability_Research/A_Guideline_of_Selecting_and_Reporting_Intraclass_Correlation_Coefficients_for_Reliability_Research.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Structure_validation_in_chemical_crystallography/Structure_validation_in_chemical_crystallography.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Understanding_the_Warburg_Effect:_The_Metabolic_Requirements_of_Cell_Proliferation/Understanding_the_Warburg_Effect:_The_Metabolic_Requirements_of_Cell_Proliferation.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Measuring_inconsistency_in_meta-analyses/Measuring_inconsistency_in_meta-analyses.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Common_risk_factors_in_the_returns_on_stocks_and_bonds/Common_risk_factors_in_the_returns_on_stocks_and_bonds.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Estimating_the_Dimension_of_a_Model/Estimating_the_Dimension_of_a_Model.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Squeeze-and-Excitation_Networks/Squeeze-and-Excitation_Networks.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Rich_Feature_Hierarchies_for_Accurate_Object_Detection_and_Semantic_Segmentation/Rich_Feature_Hierarchies_for_Accurate_Object_Detection_and_Semantic_Segmentation.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/DNA_sequencing_with_chain-terminating_inhibitors/DNA_sequencing_with_chain-terminating_inhibitors.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Two-equation_eddy-viscosity_turbulence_models_for_engineering_applications/Two-equation_eddy-viscosity_turbulence_models_for_engineering_applications.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Electrophoretic_transfer_of_proteins_from_polyacrylamide_gels_to_nitrocellulose_sheets:_procedure_and_some_applications./Electrophoretic_transfer_of_proteins_from_polyacrylamide_gels_to_nitrocellulose_sheets:_procedure_and_some_applications..html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/The_PRISMA_2020_statement:_an_updated_guideline_for_reporting_systematic_reviews/The_PRISMA_2020_statement:_an_updated_guideline_for_reporting_systematic_reviews.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/The_CES-D_Scale/The_CES-D_Scale.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Focal_Loss_for_Dense_Object_Detection/Focal_Loss_for_Dense_Object_Detection.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Self-Consistent_Equations_Including_Exchange_and_Correlation_Effects/Self-Consistent_Equations_Including_Exchange_and_Correlation_Effects.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Can_Quantum-Mechanical_Description_of_Physical_Reality_Be_Considered_Complete?/Can_Quantum-Mechanical_Description_of_Physical_Reality_Be_Considered_Complete?.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Transcript_assembly_and_quantification_by_RNA-Seq_reveals_unannotated_transcripts_and_isoform_switching_during_cell_differentiation/Transcript_assembly_and_quantification_by_RNA-Seq_reveals_unannotated_transcripts_and_isoform_switching_during_cell_differentiation.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/WGCNA:_an_R_package_for_weighted_correlation_network_analysis/WGCNA:_an_R_package_for_weighted_correlation_network_analysis.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Centrality_in_social_networks_conceptual_clarification/Centrality_in_social_networks_conceptual_clarification.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Microsoft_COCO:_Common_Objects_in_Context/Microsoft_COCO:_Common_Objects_in_Context.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/A_comprehensive_set_of_sequence_analysis_programs_for_the_VAX/A_comprehensive_set_of_sequence_analysis_programs_for_the_VAX.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/AutoDock_Vina:_Improving_the_speed_and_accuracy_of_docking_with_a_new_scoring_function,_efficient_optimization,_and_multithreading/AutoDock_Vina:_Improving_the_speed_and_accuracy_of_docking_with_a_new_scoring_function,_efficient_optimization,_and_multithreading.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/MOLSCRIPT:_a_program_to_produce_both_detailed_and_schematic_plots_of_protein_structures/MOLSCRIPT:_a_program_to_produce_both_detailed_and_schematic_plots_of_protein_structures.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Prospect_Theory:_An_Analysis_of_Decision_under_Risk/Prospect_Theory:_An_Analysis_of_Decision_under_Risk.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/BLAST+:_architecture_and_applications/BLAST+:_architecture_and_applications.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Gene_set_enrichment_analysis:_A_knowledge-based_approach_for_interpreting_genome-wide_expression_profiles/Gene_set_enrichment_analysis:_A_knowledge-based_approach_for_interpreting_genome-wide_expression_profiles.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Histograms_of_Oriented_Gradients_for_Human_Detection/Histograms_of_Oriented_Gradients_for_Human_Detection.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/A_Survey_of_Corporate_Governance/A_Survey_of_Corporate_Governance.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/U-Net:_Convolutional_Networks_for_Biomedical_Image_Segmentation/U-Net:_Convolutional_Networks_for_Biomedical_Image_Segmentation.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Deep_learning_in_neural_networks:_An_overview/Deep_learning_in_neural_networks:_An_overview.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Emergence_of_Scaling_in_Random_Networks/Emergence_of_Scaling_in_Random_Networks.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Gene_Ontology:_tool_for_the_unification_of_biology/Gene_Ontology:_tool_for_the_unification_of_biology.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Random_sample_consensus/Random_sample_consensus.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/HISAT:_a_fast_spliced_aligner_with_low_memory_requirements/HISAT:_a_fast_spliced_aligner_with_low_memory_requirements.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/A_study_of_the_conditions_and_mechanism_of_the_diphenylamine_reaction_for_the_colorimetric_estimation_of_deoxyribonucleic_acid/A_study_of_the_conditions_and_mechanism_of_the_diphenylamine_reaction_for_the_colorimetric_estimation_of_deoxyribonucleic_acid.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/WordNet/WordNet.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Ground_State_of_the_Electron_Gas_by_a_Stochastic_Method/Ground_State_of_the_Electron_Gas_by_a_Stochastic_Method.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/A_new_criterion_for_assessing_discriminant_validity_in_variance-based_structural_equation_modeling/A_new_criterion_for_assessing_discriminant_validity_in_variance-based_structural_equation_modeling.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/You_Only_Look_Once:_Unified,_Real-Time_Object_Detection/You_Only_Look_Once:_Unified,_Real-Time_Object_Detection.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Dynamic_capabilities_and_strategic_management/Dynamic_capabilities_and_strategic_management.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Molecular_portraits_of_human_breast_tumours/Molecular_portraits_of_human_breast_tumours.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Raman_Spectrum_of_Graphene_and_Graphene_Layers/Raman_Spectrum_of_Graphene_and_Graphene_Layers.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/The_PRISMA_statement_for_reporting_systematic_reviews_and_meta-analyses_of_studies_that_evaluate_healthcare_interventions:_explanation_and_elaboration/The_PRISMA_statement_for_reporting_systematic_reviews_and_meta-analyses_of_studies_that_evaluate_healthcare_interventions:_explanation_and_elaboration.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/AutoDock4_and_AutoDockTools4:_Automated_docking_with_selective_receptor_flexibility/AutoDock4_and_AutoDockTools4:_Automated_docking_with_selective_receptor_flexibility.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Delving_Deep_into_Rectifiers:_Surpassing_Human-Level_Performance_on_ImageNet_Classification/Delving_Deep_into_Rectifiers:_Surpassing_Human-Level_Performance_on_ImageNet_Classification.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/On_Information_and_Sufficiency/On_Information_and_Sufficiency.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Coefficient_alpha_and_the_internal_structure_of_tests/Coefficient_alpha_and_the_internal_structure_of_tests.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/DADA2:_High-resolution_sample_inference_from_Illumina_amplicon_data/DADA2:_High-resolution_sample_inference_from_Illumina_amplicon_data.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/clusterProfiler:_an_R_Package_for_Comparing_Biological_Themes_Among_Gene_Clusters/clusterProfiler:_an_R_Package_for_Comparing_Biological_Themes_Among_Gene_Clusters.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Preferred_Reporting_Items_for_Systematic_Reviews_and_Meta-Analyses:_The_PRISMA_Statement/Preferred_Reporting_Items_for_Systematic_Reviews_and_Meta-Analyses:_The_PRISMA_Statement.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/G*Power_3:_A_flexible_statistical_power_analysis_program_for_the_social,_behavioral,_and_biomedical_sciences/G*Power_3:_A_flexible_statistical_power_analysis_program_for_the_social,_behavioral,_and_biomedical_sciences.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Apoptosis:_A_Basic_Biological_Phenomenon_with_Wideranging_Implications_in_Tissue_Kinetics/Apoptosis:_A_Basic_Biological_Phenomenon_with_Wideranging_Implications_in_Tissue_Kinetics.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/CLUSTAL_W:_improving_the_sensitivity_of_progressive_multiple_sequence_alignment_through_sequence_weighting,_position-specific_gap_penalties_and_weight_matrix_choice/CLUSTAL_W:_improving_the_sensitivity_of_progressive_multiple_sequence_alignment_through_sequence_weighting,_position-specific_gap_penalties_and_weight_matrix_choice.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Observational_Evidence_from_Supernovae_for_an_Accelerating_Universe_and_a_Cosmological_Constant/Observational_Evidence_from_Supernovae_for_an_Accelerating_Universe_and_a_Cosmological_Constant.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/The_empirical_mode_decomposition_and_the_Hilbert_spectrum_for_nonlinear_and_non-stationary_time_series_analysis/The_empirical_mode_decomposition_and_the_Hilbert_spectrum_for_nonlinear_and_non-stationary_time_series_analysis.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Cytoscape:_A_Software_Environment_for_Integrated_Models_of_Biomolecular_Interaction_Networks/Cytoscape:_A_Software_Environment_for_Integrated_Models_of_Biomolecular_Interaction_Networks.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Fully_convolutional_networks_for_semantic_segmentation/Fully_convolutional_networks_for_semantic_segmentation.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/An_Introduction_to_the_Bootstrap/An_Introduction_to_the_Bootstrap.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Knowledge_and_Teaching:Foundations_of_the_New_Reform/Knowledge_and_Teaching:Foundations_of_the_New_Reform.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/RAxML-VI-HPC:_maximum_likelihood-based_phylogenetic_analyses_with_thousands_of_taxa_and_mixed_models/RAxML-VI-HPC:_maximum_likelihood-based_phylogenetic_analyses_with_thousands_of_taxa_and_mixed_models.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Projector_augmented-wave_method/Projector_augmented-wave_method.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Oligomerization_and_phosphorylation_of_the_Ire1p_kinase_during_intracellular_signaling_from_the_endoplasmic_reticulum_to_the_nucleus./Oligomerization_and_phosphorylation_of_the_Ire1p_kinase_during_intracellular_signaling_from_the_endoplasmic_reticulum_to_the_nucleus..html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/The_CLUSTAL_X_windows_interface:_flexible_strategies_for_multiple_sequence_alignment_aided_by_quality_analysis_tools/The_CLUSTAL_X_windows_interface:_flexible_strategies_for_multiple_sequence_alignment_aided_by_quality_analysis_tools.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Fast,_scalable_generation_of_high‐quality_protein_multiple_sequence_alignments_using_Clustal_Omega/Fast,_scalable_generation_of_high‐quality_protein_multiple_sequence_alignments_using_Clustal_Omega.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/EEGLAB:_an_open_source_toolbox_for_analysis_of_single-trial_EEG_dynamics_including_independent_component_analysis/EEGLAB:_an_open_source_toolbox_for_analysis_of_single-trial_EEG_dynamics_including_independent_component_analysis.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Differential_expression_analysis_for_sequence_count_data/Differential_expression_analysis_for_sequence_count_data.html
# 'utf-8' codec can't decode byte 0x84 in position 405171: invalid start byte
# Traceback (most recent call last):
#   File "/Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/./transcript.py", line 427, in batch_process
#     semanticize(path)
#   File "/Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/./transcript.py", line 294, in semanticize
#     dom, dimensions = prepare(doc_path)
#                       ^^^^^^^^^^^^^^^^^
#   File "/Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/./transcript.py", line 246, in prepare
#     s = open(doc_path, "rt", encoding=ENCODING).read()
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen codecs>", line 322, in decode
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x84 in position 405171: invalid start byte
#
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Full-length_transcriptome_assembly_from_RNA-Seq_data_without_a_reference_genome/Full-length_transcriptome_assembly_from_RNA-Seq_data_without_a_reference_genome.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/A_rapid_alkaline_extraction_procedure_for_screening_recombinant_plasmid_DNA/A_rapid_alkaline_extraction_procedure_for_screening_recombinant_plasmid_DNA.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Greedy_function_approximation:_A_gradient_boosting_machine./Greedy_function_approximation:_A_gradient_boosting_machine..html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Resilience_and_Stability_of_Ecological_Systems/Resilience_and_Stability_of_Ecological_Systems.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/A_Contribution_to_the_Empirics_of_Economic_Growth/A_Contribution_to_the_Empirics_of_Economic_Growth.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/RSEM:_accurate_transcript_quantification_from_RNA-Seq_data_with_or_without_a_reference_genome/RSEM:_accurate_transcript_quantification_from_RNA-Seq_data_with_or_without_a_reference_genome.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Bootstrap_Methods:_Another_Look_at_the_Jackknife/Bootstrap_Methods:_Another_Look_at_the_Jackknife.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/The_electronic_properties_of_graphene/The_electronic_properties_of_graphene.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/jModelTest_2:_more_models,_new_heuristics_and_parallel_computing/jModelTest_2:_more_models,_new_heuristics_and_parallel_computing.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/phyloseq:_An_R_Package_for_Reproducible_Interactive_Analysis_and_Graphics_of_Microbiome_Census_Data/phyloseq:_An_R_Package_for_Reproducible_Interactive_Analysis_and_Graphics_of_Microbiome_Census_Data.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Highly_accurate_protein_structure_prediction_with_AlphaFold/Highly_accurate_protein_structure_prediction_with_AlphaFold.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/QIIME_allows_analysis_of_high-throughput_community_sequencing_data/QIIME_allows_analysis_of_high-throughput_community_sequencing_data.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Cluster_analysis_and_display_of_genome-wide_expression_patterns/Cluster_analysis_and_display_of_genome-wide_expression_patterns.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Statistical_power_analyses_using_G*Power_3.1:_Tests_for_correlation_and_regression_analyses/Statistical_power_analyses_using_G*Power_3.1:_Tests_for_correlation_and_regression_analyses.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Learning_Phrase_Representations_using_RNN_Encoder–Decoder_for_Statistical_Machine_Translation/Learning_Phrase_Representations_using_RNN_Encoder–Decoder_for_Statistical_Machine_Translation.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Gradient-based_learning_applied_to_document_recognition/Gradient-based_learning_applied_to_document_recognition.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Fronts_propagating_with_curvature-dependent_speed:_Algorithms_based_on_Hamilton-Jacobi_formulations/Fronts_propagating_with_curvature-dependent_speed:_Algorithms_based_on_Hamilton-Jacobi_formulations.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Fast_unfolding_of_communities_in_large_networks/Fast_unfolding_of_communities_in_large_networks.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Studies_of_interference_in_serial_verbal_reactions./Studies_of_interference_in_serial_verbal_reactions..html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/GRADE:_an_emerging_consensus_on_rating_quality_of_evidence_and_strength_of_recommendations/GRADE:_an_emerging_consensus_on_rating_quality_of_evidence_and_strength_of_recommendations.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Self-efficacy:_Toward_a_unifying_theory_of_behavioral_change./Self-efficacy:_Toward_a_unifying_theory_of_behavioral_change..html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Asymptotic_and_resampling_strategies_for_assessing_and_comparing_indirect_effects_in_multiple_mediator_models/Asymptotic_and_resampling_strategies_for_assessing_and_comparing_indirect_effects_in_multiple_mediator_models.html
# /Users/ms/cs/ML/MLab/paper-extraction/unilex-transcript/data/HTML/Electric_Field_Effect_in_Atomically_Thin_Carbon_Films/Electric_Field_Effect_in_Atomically_Thin_Carbon_Films.html
# CompletedProcess(args='./transcript.py', returncode=0)

# %% [markdown]
# # Parse HTML with python

# %% [markdown]
# # -

# %% [markdown]
# # -

# %%
Works().filter(is_oa=True).count()
# Out:
# 53858599
